# %%
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../")
from  CommonFunc_02 import *
def daily_hello(contents = """""",daycon_num=0, log_update=True):
    import datetime as dt
    import subprocess

    now = dt.datetime.now()

    # 날짜 형식 지정
    date_format = now.strftime("%Y.%m.%d %a")
    
    # 시간 형식 지정
    if now.hour < 12:
        time_format = now.strftime("AM%I:%M")
    else:
        time_format = now.strftime("PM%I:%M")
        
    daycon = {
                    '1.트랙-첫걸음':"https://dacon.io/pblTrack/236362/edu/305",\
                    '2.트랙-첫걸음':"https://dacon.io/pblTrack/236362/edu/306",
                    '3.수화분류':"https://dacon.io/edu/323",
                    '4.xai':"https://dacon.io/edu/307",
                    '5.당뇨병 예측':"https://dacon.io/edu/1009",
                    '6.아파트경매가 예측':"https://dacon.io/edu/1014",
                    '7.중급 당뇨병 예측':"https://dacon.io/edu/1017",
                    '8.랭커특강':"https://dacon.io/forum/410560?category=ranker-videos",
                    '9.해커톤- 식당리뷰':"https://dacon.io/competitions/official/236351/overview/description"
    }
    
        
    
    for key,link in daycon.items():
            if int(key.split(".")[0])==daycon_num:
                if daycon_num:
                    print(rainbow_orange(f"\n{key}링크를 실행합니다 "))
    def  write_log(content):
        with open("hello_log.txt", "r+") as f: # "r+" 모드로 파일 열기
            if log_update:
                # 파일 내용 읽어오기
                file_content = f.read()
                # 파일 포인터를 파일 시작 부분으로 이동
                f.seek(0)
                # 새 내용을 먼저 쓰기
                f.write(content+f"\n{file_content}") # 기존 내용 추가
    write_log(f"""{date_format} {time_format}\n{contents}\n""")
    
    with open("hello_log.txt", "r") as f:
        print(red("-"*30+ "Log"+"-"*30))
        # print(rainbow_green(f.read()))
        
        lines = f.read().splitlines()
        find_last_num = False
        # 각 줄을 무지개 녹색으로 출력
        for line in lines:
            if ':' in line:
                print(yellow(line))
            elif '*' in line:
                print((red(line)))
            elif ("daycon_num" in line ) and (not find_last_num):
                last_daycon_num=int(line.split("->")[-1])
                
                find_last_num =True
            else:
                print(green(line))
                
        # 월화 수목 금토 일  분류해서 그날 해야하는 링크를 자동으로 떠오르게 만들것. 
        if last_daycon_num ==9: last_daycon_num =0
            
        for key,link in daycon.items():
            if int(key.split(".")[0])==last_daycon_num+1:
                link_act= f'/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome --remote-debugging-port=9222 --user-data-dir="/Users/<>/Applications/Google Chrome.app/" --new-tab {link}'
                # !{link_act}

        last_daycon_num+=1
        write_log(f"daycon_num-> {last_daycon_num}")
        # !/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome --remote-debugging-port=9222 --user-data-dir="/Users/<>/Applications/Google Chrome.app/" --new-tab https://school.programmers.co.kr/learn/challenges/
        import time
        time.sleep(1)
        # !/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome --remote-debugging-port=9222 --user-data-dir="/Users/<>/Applications/Google Chrome.app/" --new-tab https://www.acmicpc.net/problem/2941

# %%
    
    
daily_hello("""
    오늘은 아침에 좀 늦게 일어나서 정신이 없다. 오후에 강의를 듣도록 하자. 
    로그파일 정리도 좀 해야겠다..
""",log_update=True)
# Out:
# ------------------------------Log------------------------------
# 2024.09.25 Wed AM08:36
#
#     오늘은 아침에 좀 늦게 일어나서 정신이 없다. 오후에 강의를 듣도록 하자.
#     로그파일 정리도 좀 해야겠다..
#
#
# 2024.09.24 Tue PM03:33
#
#     이제 시작해보자!
#
#
# 2024.09.24 Tue PM03:32
#
#     이제 시작해보자!
#
#
# 2024.09.24 Tue PM03:32
#
#     이제 시작해보자!
#
#
#
#
# daycon_num-> 1
# 2024.09.24 Tue PM03:30
#
#     백준도 뜨개했디
#
#
# daycon_num-> 2
# 2024.09.24 Tue PM03:28
#
#     프로그래머스도 뜨게했다
#
#
#
# daycon_num-> 1
# 2024.09.24 Tue PM03:13
#
#     test 완료했다. 가장 마지막에 실행된 링크로 데이콘창이 뜰것이다.
#
#
#
#
# daycon_num->0
# 2024.09.24 Tue PM03:04
#
#     매일 데일리 헬로우를 할때 한줄요약을 실천하자 한줄요약하는 줄은 *로 시작하자.
#     그리고 가장 최근에 실행한 데이콘 링크 이후의 링크를 실행하도록 설정했다.
#
#
#
#
#
#
# 2024.09.24 Tue PM02:37
#
#     매일 데일리 헬로우를 할때 한줄요약을 실천하자 한줄요약하는 줄은 *로 시작하자.
#     그리고 가장 최근에 실행한 데이콘 링크 이후의 링크를 실행하도록 설정했다.
#
#
#
# 2024.09.23 Mon PM08:49
#
#     정리에 대해서 고민해보자.
#     저녁시간에 한시간정도 산책을 하면 머리가 정리되고 하루가 정리가 된다.
#     정리된 마음이 이렇게 이야기 했다.
#     루틴에 목숨을 걸어라.
#
#
#
#
# ...

# %% [markdown]
# 문제해결 : https://explored.tistory.com/entry/python-chromedriver-Exec-format-error

# %%
# !/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome --remote-debugging-port=9222 --user-data-dir="/Users/<>/Applications/Google Chrome.app/" --new-tab https://www.acmicpc.net/problem/2941
# Out:
# Opening in existing browser session.
