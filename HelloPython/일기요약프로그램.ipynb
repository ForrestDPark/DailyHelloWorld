# %%
from CommonFunc_03 import *

# %%
import pandas as pd
yellow("asdf")
# Out:
# '\x1basdf\x1b'

# %%
columns ={'date':'TEXT UNIQUE','time':'TEXT','summary':'TEXT'}
# Out:
# date TEXT UNIQUE,
# time TEXT,
# summary TEXT,

# %%
def sqlite_datbase_gen(
    ## 2024.10.21 diary 쓰기 위해 만듬....
    dbPath ='./Data/diary.sqlite',
    dbName ='diary',
    columns ={'date':'TEXT UNIQUE','time':'TEXT','summary':'TEXT'}
    ):
    import sqlite3
    conn = sqlite3.connect(dbPath)
    ## table 생성하기 
    conn = sqlite3.connect(dbPath)
    curs = conn.cursor()
    
    query = ''
    for order,i in enumerate(columns.keys()):
        if order ==0 :
            query+=  i + f" {columns[i]}, \n"
        elif 0<order <len(columns.keys())-1:
            query+= "\t    "+ i + f" {columns[i]}, \n"
        else:
            query+= "\t    "+i + f" {columns[i]}"
    print(query)
    script = f"""
        DROP TABLE IF EXISTS {dbName};
        CREATE TABLE {dbName}(
            {dbName}_id INTEGER PRIMARY KEY AUTOINCREMENT,
            {query}
        );
        INSERT INTO diary(date, time, summary) VALUES ('2024.09.03','05:49','mircle 루틴 시작, 내가 만들기 원하는것' );
        """
    print(script)
    curs.executescript(script)
    curs = conn.cursor()
    column_list_str = [ f'{i}, 'if order<len(columns.keys())-1 else f'{i}' for order,i in enumerate(list(columns.keys()))]
    # print(''.join(column_list_str))
    select_script = f"SELECT {dbName}_id , {''.join(column_list_str)} FROM {dbName}"
    print(yellow(select_script))
    curs.execute(select_script)
    item_list = curs.fetchall()
    for it in item_list:
        print(it)
    conn.commit()
    curs.close()
    conn.close()
# sqlite_datbase_gen()


def sqlite_db_insert(
    dbPath ='./Data/diary.sqlite',
    dbName ='diary',
    date ='',
    summary='',
    time=''
):
    import sqlite3
    # sqlite 데이터베이스 연결하기 


    conn = sqlite3.connect(dbPath)

    # 데이터 넣기 
    curs = conn.cursor()
     # 칼럼 이름 추출
    curs.execute(f"PRAGMA table_info({dbName})")
    column_names = [row[1] for row in curs.fetchall()]
    colums_str=(', '.join(column_names[1:]))
    values_qmarkers = ", ".join(['?' for i in range(len(column_names[1:]))])
    
    if date:
        query = f'INSERT INTO {dbName} ({colums_str}) VALUES ({values_qmarkers})'
        curs.execute(query, ((date,time,summary)))
    
    # 데이터 추출하기 
    curs = conn.cursor()
    curs.execute(f"SELECT {dbName}_id, {colums_str} FROM {dbName} ORDER BY {dbName}_id DESC")
    item_list = curs.fetchall()
    # 
    for it in item_list:
        print(red(f"{it[0]}"),yellow(' '.join(it[1:3])),rainbow_blue(it[3]))
    conn.commit()
    import pandas as pd 
    df = pd.DataFrame(item_list,columns=column_names,index=None)
    df.to_csv('./Data/diary.csv',index=False,index_label=None)





def sqlite_db_update(
    dbPath='./Data/diary.sqlite',
    dbName='diary',
    diary_id=None,  # 수정할 diary_id
    date=None,
    summary=None,
    time=None
):  
    import sqlite3
    conn = sqlite3.connect(dbPath)
    curs = conn.cursor()

    # 수정할 칼럼과 값을 추출
    update_fields = []
    update_values = []
    if date:
        update_fields.append('date')
        update_values.append(date)
    if summary:
        update_fields.append('summary')
        update_values.append(summary)
    if time:
        update_fields.append('time')
        update_values.append(time)

    # 업데이트 쿼리 구성
    if update_fields:
        set_clause = ', '.join(f"{field} = ?" for field in update_fields)
        query = f"UPDATE {dbName} SET {set_clause} WHERE {dbName}_id = ?"
        curs.execute(query, tuple(update_values) + (diary_id,))  # 값과 id를 튜플로 전달
        conn.commit()
        print(f"diary_id {diary_id}가 성공적으로 업데이트되었습니다.")
    else:
        print("수정할 데이터가 없습니다.")

    curs.close()
    conn.close()

# 예시: diary_id가 1인 항목의 요약을 "새로운 요약"으로 업데이트
# sqlite_db_update(diary_id=15,
# summary="""
#     1. 자기애 지출(프로틴-무당, 마그네틱쉐이크가방,쉐이커뚜껑, 찻주전자, 로즈마리티백)
#     2. 저녁 독서 피로 게임으로 이어짐
#     3. 성욕,도파민 아껴서 아침운동시 폭발 마인드 채택, 상상력 훈련
#     4. 매일꾸준히 한시간저도 그시간에 할수있는것이 프로의 출발선, 매일 hello world 치기 시작
# """
# )


sqlite_db_insert()
# Out:
# diary_id 15가 성공적으로 업데이트되었습니다.
# 15 2024.09.18 AM08:28
#     1. 자기애 지출(프로틴-무당, 마그네틱쉐이크가방,쉐이커뚜껑, 찻주전자, 로즈마리티백)
#     2. 저녁 독서 피로 게임으로 이어짐
#     3. 성욕,도파민 아껴서 아침운동시 폭발 마인드 채택, 상상력 훈련
#     4. 매일꾸준히 한시간저도 그시간에 할수있는것이 프로의 출발선, 매일 hello world 치기 시작
#
# 14 2024.09.17 AM08:11
#     1. 피곤함-게임 악순환 끊기 위해 저녁루틴 고민
#     2. LLSMIDF(세탁,음료,피부,명상,시각화,어둠,폼롤러)
#     3. 확언2주 점점 구체화됨을 느낌, 미래에 대한 확신
#     4. 잔소리는 수용 불가자의 태도. 침묵자는 기다리며 에고를 녹인다.
#     <PM05:40>
#     1. 강동역 셀러그리티 육회셀러드+바질올리브소스+ 닭가슴살
#     2. 오후에 루틴해보았으나 의지,의욕,에너지 모두 부족, 명상은 에너지많은 아침에 하자
#     3. 루틴아닌 시간에 무엇을 해야하나? 고민중, 일단 기록하는데 시간 써보자
#
# 13 2024.09.16 AM09:07
#     1. 책상자리배치 항상 같게, 기상후 마음도 항상같게
#     2. 여자생각, 전날잔상념 보다 나자신을 바라보는것이 낫다
#     3. 마이아르반응 독으로세뇌됨. 마트 90% 불가, 수육뿐..
#
# 12 2024.09.15 AM07:21
#     <지하철>
#     1. 아차산 등반
#     2. 상쾌함 -긍정적사고를 위한 휴일루틴
#     3. 휴일은 무조건 산 입구찍고 오는것을 미니루틴으로
#
# 11 2024.09.14 AM07:50
#     1. 지나간것은 전부 좋은 경험
#     2. 과거는 오지않고 미래는 반드시온다
#     3. 루틴불가 확언은 본심x , 조바심일뿐
#
# 10 2024.09.13 AM07:48
# ...

# %%
sqlite_db_insert(
    date ="2024.09.21",
    time = 'AM05:58',
    summary="""
1.
    """
)
# Out:
# 17 2024.09.20 AM09:45
#     1. 승희와 카톡
#     2. 완벽 or 지옥 같은 미래도 현재와 같은 루틴으로.
#     3. 오늘 웃는자가 최후에도 웃게 될것이다 -니체
#     4. 오늘이 마지막 날인것 처럼 살아라. 나의 마지막을 상상해보고 그날과 오늘의 루틴을 갖게 만든다면 그말이 실현된것이다.
#
#
# 16 2024.09.19 AM06:26
#     1. 저속 정성글씨, 일정박자 펜압 심신안정,즐거운기분
#     2. 병원일상 미라클 완료 수면질 좋음(당독소 다이어트 효과인듯)
#     3. 필사 노션작업 간략화, 패드에 한쪽 사진 입력후 밑줄
#
#
# 15 2024.09.18 AM08:28
#     1. 자기애 지출(프로틴-무당, 마그네틱쉐이크가방,쉐이커뚜껑, 찻주전자, 로즈마리티백)
#     2. 저녁 독서 피로 게임으로 이어짐
#     3. 성욕,도파민 아껴서 아침운동시 폭발 마인드 채택, 상상력 훈련
#     4. 매일꾸준히 한시간저도 그시간에 할수있는것이 프로의 출발선, 매일 hello world 치기 시작
#
# 14 2024.09.17 AM08:11
#     1. 피곤함-게임 악순환 끊기 위해 저녁루틴 고민
#     2. LLSMIDF(세탁,음료,피부,명상,시각화,어둠,폼롤러)
#     3. 확언2주 점점 구체화됨을 느낌, 미래에 대한 확신
#     4. 잔소리는 수용 불가자의 태도. 침묵자는 기다리며 에고를 녹인다.
#     <PM05:40>
#     1. 강동역 셀러그리티 육회셀러드+바질올리브소스+ 닭가슴살
#     2. 오후에 루틴해보았으나 의지,의욕,에너지 모두 부족, 명상은 에너지많은 아침에 하자
#     3. 루틴아닌 시간에 무엇을 해야하나? 고민중, 일단 기록하는데 시간 써보자
#
# 13 2024.09.16 AM09:07
#     1. 책상자리배치 항상 같게, 기상후 마음도 항상같게
#     2. 여자생각, 전날잔상념 보다 나자신을 바라보는것이 낫다
# ...

# %% [markdown]
# ## 일기 요약본 작성

# %%
def read_db_dataframe():
    # mysql 로 일기 관리 프로그램 제작 24.10.21
    # !pip install sqlalchemy
    import pandas as pd
    from sqlalchemy import create_engine
    engine = create_engine("mysql+pymysql://root:qwer1234@127.0.0.1:3306/diary")
    conn = engine.connect()
    data = pd.read_sql_table('diary',conn)
    # df_display_centered(data)
    return data 
    
data = read_db_dataframe()
data
# Out:
#    diary_id diary_summary       date time
# 0         1             2 2024-10-10

# %%
def mysql_db_select():
    import pymysql
    conn = pymysql.connect(
        host= '127.0.0.1',
        user = 'root',
        password = 'qwer1234',
        db = 'diary',
        charset = 'utf8'
    )
    curs = conn.cursor()
    sql = "select * from diary"
    curs.execute(sql)
    rows = curs.fetchall()

    
    # 칼럼 이름을 가져오기
    column_names = [desc[0] for desc in curs.description]
    print(column_names)  # 칼럼 이름 출력
    conn.close()
    
    rowList = list(rows)
    for i in rowList:
        print(i)
        
        
def insert_mysql():
    import pymysql
    conn = pymysql.connect(
        host= '127.0.0.1',
        user = 'root',
        password = 'qwer1234',
        db = 'diary',
        charset = 'utf8'
    )
    curs = conn.cursor()
    sql = "select * from diary"
    curs.execute(sql)
    # 칼럼 이름을 가져오기
    column_names = [desc[0] for desc in curs.description]
    print(column_names)  # 칼럼 이름 출력
    
    

insert_mysql()
# Out:
# ['diary_id', 'diary_summary', 'date', 'time']
