# %% [markdown]
# # [카테고리] 백엔드 로드맵
# ---
# <br>
# 📌 요약 <br>
# 📌 [참고] <br>
#
# ---
# 백엔드 환경
# - 자바/코틀린의 스프링
# - 파이썬 장고/플라스크
# - Go의  gin
# - C# 의 .NET Framework
# - JS의 Node.js(Express/NestJS)
#
# 타입스크립트는 객체지향 프로그래밍
# - 정적 타입 문법을 추가한 언어, 팀작업에 좋음. ES6 기반 새로운 문법 제공, JS 와 완벽호환
# -  MS 의 지원을 받음.
#
# Node.js 란?
# - 서버단에서 JS 실행할 수있는 런타임.
# - 요구사항 많고 빠르게 변하는 환경 개발에서 좋음.
# - 프론트와 같은 코드 사용. 개발시간 단축 시스템 안정성 좋음.
#
# Express 란?
# - Node.js 에서 가장 많이 사용되는 웹 프레임 워크
# - 미니멀리스트 프레임워크 지향, 확장 용이, 많은 확장 라이브러리
#
# NestJS 란?
# - JS 최신 기술 적용, 생산성 있는 웹 에플리케이션 제작, 안정적 웹 프레임워크
#
#
# Node.js 서버프레임워크는 NestJS 채택하는 추세. 현업에서는 express 도 사용

# %% [markdown]
# ---

# %% [markdown]
# # [백엔드] 백엔드 개발 트랜드와 개발환경에 대하여
# ---
# <!--이글을 쓰게 된 이유는?-->
# 백엔드 개발의 트랜드와 Node.js, NestJS, 타입스크립트, Express 에 대해 간략하게 알아보자
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 백엔드 개발 환경에는 어떤 것이 있을까?</span>
# 백엔드 환경
# - 자바/코틀린의 스프링
# - 파이썬 장고/플라스크
# - Go의  gin
# - C# 의 .NET Framework
# - JS의 Node.js(Express/NestJS)
#
# # <span style="color:#f17c6cff"> 🤔 타입 스크립트란?</span>
# 타입스크립트는 객체지향 프로그래밍
# - 정적 타입 문법을 추가한 언어, 팀작업에 좋음. ES6 기반 새로운 문법 제공, JS 와 완벽호환
# -  MS 의 지원을 받음.
#
#
# # <span style="color:#f17c6cff"> 🤔 Node.js 란?</span>
# Node.js 란?
# - 서버단에서 JS 실행할 수있는 런타임.
# - 요구사항 많고 빠르게 변하는 환경 개발에서 좋음.
# - 프론트와 같은 코드 사용. 개발시간 단축 시스템 안정성 좋음.
#
#
# # <span style="color:#f17c6cff"> 🤔Express 란?</span>
# - Node.js 에서 가장 많이 사용되는 웹 프레임 워크
# - 미니멀리스트 프레임워크 지향, 확장 용이, 많은 확장 라이브러리
#
# # <span style="color:#f17c6cff"> 🤔 NestJS 란?</span>
# - JS 최신 기술 적용, 생산성 있는 웹 에플리케이션 제작, 안정적 웹 프레임워크
#
# # <span style="color:#f17c6cff"> 🤔 백엔드 개발 트랜드는 어떻게 될까?</span>
# Node.js 서버프레임워크는 NestJS 채택하는 추세. 현업에서는 express 도 사용

# %% [markdown]
# # [Node.js]. Node.js 개발 환경 구축하기(feat.MAC)
# ---
# <!--이글을 쓰게 된 이유는?-->
# ### 테스트 환경
# 1. Visual studio code : 1.96.2(Universal)
# 2. Node.js : 20.18.1
# 3. 운영체제 : Mac OS 14.6.1
#
# ***
#
# # 1.Node.js 설치
# https://nodejs.org
#
# <img src="https://blog.kakaocdn.net/dn/DbA3T/btsLz9ECmyx/sxbOavoeyclarM07TemPIk/img.png" data-mce-src="https://blog.kakaocdn.net/dn/DbA3T/btsLz9ECmyx/sxbOavoeyclarM07TemPIk/img.png" data-origin-width="770" data-origin-height="1116" data-is-animation="false" width="328" height="475" data-mce-selected="1">
#
#
# <img src="https://blog.kakaocdn.net/dn/HcDTh/btsLCtO5OuX/CmfCOmMbxNEhgg5KmdxCt0/img.png" data-mce-src="https://blog.kakaocdn.net/dn/HcDTh/btsLCtO5OuX/CmfCOmMbxNEhgg5KmdxCt0/img.png" data-origin-width="1248" data-origin-height="506" data-is-animation="false" width="390" height="158" data-mce-selected="1">
#
#
# # 2. Node.js hello world
# # git clone :
# https://github.com/wapj/jsbackend
#
# ```Bash
# cd jsbacend/chapter0
# node hello-node.js
# ```
#
#
# 📌 참고 1.[Node.js 백엔드 개발자 되기 2024] <br>

# %% [markdown]
# ---

# %% [markdown]
# # [백엔드]. 백엔드 대하여 01 (업무순서, 설계방식)
# ---
# <!--이글을 쓰게 된 이유는?-->
# 백엔드를 개발하기 위해서 알아야 할 것은 무엇인지, 백엔드 업무 프로세스, 설계방식에 대해 알아보았습니다.
# ***
#
# <!-- Questions-->
# # 1. 백엔드에 대하여
# # <span style="color:#f17c6cff"> 🤔 백엔드란?</span>
# >#### ✅ <span style="color: #0051abff">**백엔드**</span> 는 <span style="background-color: #fff5b1">**시스템의 뒷단으로 요청에 응답하게 데이터와 정보를 처리한다**</span> 이다.
#
#
# # <span style="color:#f17c6cff"> 🤔 백엔드 개발할 때 알아야할 지식은?</span>
# >#### ✅ <span style="color: #0051abff"> 서버, 운영체제, 네트워크(http, tcp/udp, 라우팅 ,OSI, 요청, 응답, DNS)를 알아야한다. <br><br>
#
# # <span style="color:#f17c6cff"> 🤔 서버란?</span>
#
# >#### ✅ <span style="color: #0051abff">  서버란 요청을 받아 처리하고 결과물을 응답하여 보내는 주체이다. <br><br>
#
# <!--그것을 어떻게 분류 할수있나요? -->
# #### 이미지, 파일, 데이터처리 무엇을 처리할 것인지로 어떤 종류의 서버인지 분류 할 수 있다.
# ### &emsp; 1) WAS(Web application server) : <br>
# #### &emsp;&emsp;  동적 데이터 처리서버, 웹서버뒤에서 응답 제공 (ex. 톰캣, 웹스피어, JEUS,IIS)
# ### &emsp; 2) 웹서버:<br>
# #### &emsp;&emsp;  웹페이지, 파일, 이미지 등 정적 파일 서비스 (ex. Apache HTTP, Nginx,IIS)
#
# #### 정적 파일 처리는 Nginx 같은 웹서버가 훨씬 잘한다. WAS 는 스플이이나 장고 같은 웹 프레임워크를 실행 시켜 요청 받은 데이터를 처리하는 역할을 잘한다.
#
#
# # <span style="color:#f17c6cff"> 🤔 백엔드 네트워크 구성?</span>
# >#### ✅ <span style="color: #0051abff">  클라이언트가 DNS 서버로 ip 를 물어보고 DNS서버 가 알려준 IP 로 요청을 보내면 웹서버가 응답을 보낸다. <br><br>
# <img src="https://blog.kakaocdn.net/dn/b03u14/btsLBf6a6J0/B88wrrKahwq2mOJBOhjZxk/img.png" data-mce-src="https://blog.kakaocdn.net/dn/b03u14/btsLBf6a6J0/B88wrrKahwq2mOJBOhjZxk/img.png" data-origin-width="612" data-origin-height="426" data-is-animation="false" data-mce-selected="1">
#
#
#
#
# - 캐시 : 디스크가 아니라 메모리에 데이터 저장 읽는 속도 높이는 방식
# - 프레임워크 :
# 개발에 필요한 예외 처리, 데이터베이스 연결, 외부 라이브러리 연동
# 코드 구조 일관성을 줌. 개발자가 비즈니스 로직 개발에 집중 가능.
#
#
# # 2. 백엔드 개발자가 수행하는 업무 순서
# 1. **과제 할당 및 분석** : 구체적 개발 관점 검토
#      ex) 친구 초대 이벤트 -> 친구?, 초대? 무슨의미 어떤 조건, 이벤트를 위해 어떤 데이터를 저장할지 등등..+ 제공할 성능과 사용할 기술 검토
#
# 2. **개발-> 테스트 -> 분석** : 완성도를 높이는 과정
#
# 3. **QA(Quality Assurance)**: 성능결함, 로직오류 검증
# 4. **배포** : 롤링배포(서버 돌아가며), 블루그린(로드밸런서 설정변경), 카나리(문제 없는 서버 배포비율 늘림)
# - 도커 사용시 앤서블(Ansible)로 롤링 배포 구현 가능.
#
# 5. **유지 보수**
# - 개발 부터 배포, 모니터링 무한 반복 (CICD) : DevOps  개발과 운영 합성함.
# - DevOps 클라우드 마이그래이션, 피크타임 트래픽 처리, 데이터 파이프라인 작성, 모니터링 시스템 구축
# - 네트워크 보안,코드를 통한 인프라 관리
# - 문서 관리 및 유지보수 인계작업 등
#
# # 3. 백엔드 아키텍처
#
# # <span style="color:#f17c6cff"> 🤔 아키텍트란?</span>
# > ### ✅ <span style="color: #0051abff">**아키텍트**</span> 는 <span style="background-color: #fff5b1">** 개발을 위한 총체적,종합적 기획**</span> 이다.
#
#
# <!--그것을 어떻게 분류 할수있나요? -->
# #### 💁‍♂️ 아키텍쳐는 계층형, 이벤트기반, 마이크로 서비스의 구조로 분류 할 수 있습니다.
# ### &emsp;1) 계층형(layerd architecture) :<br>
# - 가장단순, 직관적, 논리적 분리, 소규모 애플리케이션에서 채택
# - 프레젠테이션, 비즈니스로직, 데이터 저장 계층 수행
# - 의존성이 단방향임. <br><img src="https://blog.kakaocdn.net/dn/BBUg4/btsLAZPGBEE/Z79zUdh7Fdz5SDuOushkj0/img.png" data-mce-src="https://blog.kakaocdn.net/dn/BBUg4/btsLAZPGBEE/Z79zUdh7Fdz5SDuOushkj0/img.png" data-origin-width="986" data-origin-height="750" data-is-animation="false" width="455" height="346" data-mce-selected="1">
#
#
# ### &emsp;2) 이벤트 기반(event-driven architecture):<br>
# - 이벤트 상태 변화에 대응 하는 설계 패턴
# - 프로듀서(이벤트 발생), 브로커(이벤트 전달), 컨슈머(이벤트 받음)
# - 모든 요청 비동기 처리, 확장성, 컴포넌트간 의존성 줄임.
# - 수평적 확장(Scale out)용이(장비 추가로 처리량 증대)
# - 에러 발생시 이벤트 새로 생성, 무시, 에러처리 중 고려 <br><img src="https://blog.kakaocdn.net/dn/TiFpa/btsLCs3OHla/W9b6fsLpB27ngna9YrMIL0/img.png" data-mce-src="https://blog.kakaocdn.net/dn/TiFpa/btsLCs3OHla/W9b6fsLpB27ngna9YrMIL0/img.png" data-origin-width="922" data-origin-height="444" data-is-animation="false" width="484" height="233" data-mce-selected="1">
#
#
#
# ### &emsp;3) 마이크로서비스 (microservices architecture):<br>
# - 여러개의 작은 서비스로 나누어 관리
# - 독립적 개발, 배포, 운영, 구조적 분리
# - 각 서비스의 독립적 업데이트 및 스케일링 가능
# - 간결한 전체 구조 , 대규모 시스템 구축에 유용, 확장성 좋음, 업그레이드 용이,
# - 도메인 주도 설계에 영향을 받음.
# - 도메인: 사용자가 요구하는 문제 분야 내에서의 상황 ex) 계정관리, 상품관리 등.
# - 유지보수에 비용 많이 들어감. <br><img src="https://blog.kakaocdn.net/dn/bDbwhK/btsLDfQB4kC/YgsrNLE4TnKh1XR4NkmF51/img.png" data-mce-src="https://blog.kakaocdn.net/dn/bDbwhK/btsLDfQB4kC/YgsrNLE4TnKh1XR4NkmF51/img.png" data-origin-width="1138" data-origin-height="728" data-is-animation="false" width="469" height="300" data-mce-selected="1">
#
#
# 백엔드의 정의 와 백엔드 프로세스 그리고 백엔드 설계에 대하여 알아보았습니다.
#
#
#
# 📌 참고 1.[도서,Node.js백엔드 개발자 되기 ]() <br>

# %% [markdown]
# # [백엔드]. 백엔드 프로그래밍 언어 정리
# ---
# <!--이글을 쓰게 된 이유는?-->
# 백엔드 개발할때 알아야하는 프로그래밍 언어와 타입스크립트에 대해 알아보겠습니다.
# ***
#
# <!--그것을 어떻게 분류 할수있나요? -->
# # <span style="color:#f17c6cff">  💁‍♂️ 백엔드 프로그래밍 언어 종류</span>
#
# #### 1) Python :Flask, Jango, FastAPI
# #### 2) C++ : 게임서버 개발
# #### 3) Java : Spring Framework
# #### 4) C# : MS 계열 소프트웨어 (ex. stack over flow)
# #### 5) JavaScript : 개발자 소수 일때 풀스택 언어(프론트,백엔드,타입스크립트,인프라,서버리스,앱개발 가능)
#
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔타입 스크립트란?</span>
# > ### ✅ <span style="color: #0051abff">**타입 스크립트란**</span> 는 <span style="background-color: #fff5b1">**원하는 타입으로 엄격하게 정의(Static) 가능한 JavaScript 오픈소스 언어**</span> 입니다.
# - 컴파일 과정에서 타입 지정하여 컴파일 에러 예방 및 손쉬운 디버깅 가능(개발단계에서 에러 발견)
# - 안정적인 개발과 높은 수준의 코드 품질을 유지 하게 함.
# - 정적타입의 컴파일언어로 타입스크립트 컴파일러를 통해 자바스크립트 코드로 변환된다.
# - 객체 지향 프로그래밍 패턴 제공
# - JS 엔진에 기본 모듈 설치필요, 컴파일 옵션 설정,타입 지정에 시간 걸릴수 잇음.
# - .ts 확장자 사용
#
# <!-- 차이점은 무엇인가요 ? -->
# # <span style="color:#f17c6cff"> ⚖️  동적 타이핑과  정적타이핑 의 비교 </span>
# #### **⭐️ 변수의 타입을 지정해주면 정적(Static) 컴퓨터가 알아서 정하면 동적(Dynamic) 이다.**
# - 동적타이핑
#     - 코드 작성시 컴퓨터적 구조 생략함.
#     - 변수 지정할때 type 지정 안하고 컴퓨터가 알아서 해석함.실행속도 느림
#     - 파이선, 루비, JavaScript
# - 정적 타이핑
#     - 구조를 명시해줌. 코드 구조 파악 쉬움. 크고 복잡하고 여러사람 참여 프로젝트에 적합.
#     - c,C++,java 등
#
#
#
# 📌 참고 1.[도서,Node.js백엔드 개발자 되기 ](https://product.kyobobook.co.kr/detail/S000201457949)
# 📌 참고 2.[티스토리, 2021, 동적 정적 타이핑 비교](https://seongonion.tistory.com/16)
# 📌 참고 3. [Velog, 2023, typescript 소개](https://velog.io/@dhcod/TypeScript-%EC%86%8C%EA%B0%9C-TypeScript%EB%A5%BC-%EC%82%AC%EC%9A%A9%ED%95%98%EB%8A%94-%EC%9D%B4%EC%9C%A0)

# %% [markdown]
# # [백엔드]. 백엔드 데이터베이스 정리
# ---
# <!--이글을 쓰게 된 이유는 무엇인가요?-->
# 백엔드에 사용되는 데이터 베이스에 대해서 알아보자.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 데이터베이스란?</span>
# > ### ✅ <span style="color: #0051abff">**데이터베이스**</span> 는 <span style="background-color: #fff5b1">**검색과 축적이 쉽도록 정리된 데이터 모음 혹은 그것을 가능하게하는 소프트웨어**</span> 이다.
# - 메모리, 텍스트파일, 엑셀, 특정프로토콜을 통해 생성한 바이너리 파일 등의 데이터를 검색, 수정삭제,읽기 요총이 동시 다발적 처리와 응답이 가능해야함.
# - 데이터 저장 시 수많은 문제 가 생기는 상황에서도 데이터를 안전하게 CRUD 가능하도록 하는 소프트웨어.
# - Oracle, MySQL(무료), MariaDB, SQL Server, PostgreSQL, SQLite, MongoDB, Cassandra, DynamoDB, Neo4j, CockroachDB, 알티베이스(국산), 큐브리드(국산), 티베로(국산)
#
#
# <!--그것을 어떻게 분류,구별 할수있나요? -->
# # <span style="color:#f17c6cff"> 💁‍♂️ 데이터베이스는 RDB 와 NoSQL 로 분류됩니다.</span>
# ### <span style="color:#0051abff"> **1) RDB(Relational Database) : 관계형 데이터 베이스.(row,column 으로 이루어진 테이블 형태, primary key 로 레코드 식별, 테이블간 관계 생성)**</span> <br>
# - ACID : (Atomicity-원자성, Consistency-일관성, Isolation-격리성, Durability-내구성)
#     - 원자성 : 트랜젝션을 구성하는 명령이 하나의 묶음으로 처리되어 함께 성공, 실패됨을 보장하는 기법.
#     - 일관성 : 트랜젝션에서 실행된 변경 사항이 데이터베이스의 무결성 조건을 만족시킴.
#     - 격리성 : 두개의 트랜젝션이 서로에게 영향을 미칠수 없는 성질
#     - 내구성 : 트랜젝션 성공시 그 결과가 계속 유지되며 문제발생시 이전의 상태로 되돌릴수 있음.
# - SQL ( Structured Query Language): 데이터 탐색용 프로그램언어, ANSI 표준이 있음.
# - RDB 는 CRUD 용이하나 성능 올리는게 쉽지 않음. 머신성능 스케일업 또는 머신 분리하는 스케일 아웃 필요
# - 스케일 업은 비용이 들고 스케일아웃은 트랜젝션 사용시 성능 저하 일으킴.
#
#
# ### <span style="color:#0051abff"> **2) NoSQL(Not Only SQL) : 비관계형 + 분산데이터베이스를 가정한 키-벨류 형태 DB**</span><br>
# - 데이터 규모가 커지면 키 벨류캐시, 키밸류 스토어, 도큐먼트 스토어, 와이드 칼럼 스토어 사용.
# - **키밸류 캐시 :**
#     Memcached, Redis가 많이 사용됨
#     클러스터를 쉽게 지원하여 분산환경에서 편하게 사용가능. 캐시는 서버 재시작시 데이터 휘발.
#     - Memecached: 키 밸류 형태의 데이터만 제공.(멀티 스레드)
#     - Redis : 다양한 데이터 구조 지원, 싱글 스레드(오래걸리는 작업시 서버 정지)
# - **키 벨류 스토어**
#     다이나모디비,카우치베이스(Courchbase)가 많이 사용됨,데이터비휘발, 업데이트 자주 일어날때 사용.
# - **도큐먼트 스토어**
#     몽고디비 많이 사용.
#     - Json 과 매우 비슷한 BSON 문서 모델 저장.
#     JSON(JavaScript Object Notation): 데이터 저장 및 전송시 사용하는 경량 데이터 표현 방식 ,JS 객체 형식 기반
#     - 테이블 개념인 컬랙션이라는 개념. 검색시 인덱스사용, ACID 트랜젝션 지원등 RDB 에서 사용했던 기능 사용 가능
# - **와이드 컬럼 스토어**
#     행과 열 테이블 사용, RDB 와 차이점은 행마다 열의 이름과 타입이 다를수 있다는 점.
#     - 2차원 키 벨류 저장소로 사용가능.
#     - 구글 Bigtable
#     - 아파치 카산드라(단일장애점, single point of failure,SPOF) 이 없음. 확장성, 성능 뒤어남.
#
#
#
# 📌 참고 1.[도서,Node.js백엔드 개발자 되기 ](https://product.kyobobook.co.kr/detail/S000201457949) <br>

# %% [markdown]
# # [백엔드]. 클라우드 서비스 정리
# ---
# <!--이글을 쓰게 된 이유는 무엇인가요?-->
# 서버 관리와 배포를 위해 사용되는 클라우드 서비스에 대해서 정리해 보겠습니다.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 클라우드 서비스란?</span>
# > ### ✅ <span style="color: #0051abff">**클라우드**</span> 는 <span style="background-color: #fff5b1">**물리적 서버(IDC,Internet data center)없이 인터넷으로 사용가능한 서버 인프라**</span> 이다.
# - 많은 서버의 CPU, 메모리, 네트워크 대역폭 서비스
# - 장비 문제시 다른 장비의 자원으로 손쉽게 교체 가능
# - 서버 자원의 탄력적 제공
# - AWS, AZURE, GCP(google)
# - 1분단위 과금기준
# - 스팟인스턴스 or 스팟vm 서비스 : 유휴자원 서버 저렴한 사용 가능
#
# <!--그것을 어떻게 분류,구별 할수있나요? -->
# # <span style="color:#f17c6cff"> 💁‍♂️ 클라우드는 컴퓨팅 유형으로 분류됩니다.</span>
# ### <span style="color:#0051abff"> **1) IaaS(Infrasturcture as Service)**</span> <br>
# - 서버, 스토리지, 네트워킹 등 컴퓨팅 자원 사용
#
# ### <span style="color:#0051abff"> **2) PaaS(Platform as a Service)**</span> <br>
# - 인프라 필요없이 코드작성하면 환경 구성, 애플리케이션 구축에 집중가능,
# - 서버 프로비저닝, 리소스 확장 및 인프라 관리 작업 처리
# - Heroku, AWS Elastic Beanstalk, Azure App Service, App Engine(GCP)
#
# ### <span style="color:#0051abff"> **3) SaaS(Software as Service)**</span> <br>
# - 브라우저를 통한 애플리케이션 패키지 사용 서비스
# - Google docs, MS 365, 어도비 크리에이티브 클라우드
#
#
# # <span style="color:#f17c6cff"> 💁‍♂️ AWS, Azure, GCP 기능비교</span>
#
#
#
# | 기능        |  AWS                              | Azure                        | GCP                                  |
# |-----------|-----------------------------------|------------------------------|--------------------------------------|
# | 컴퓨팅       | EC2, Elastic Beanstalk            | Virtual Machines,AKS         | Compute Engine, Kubernetes           |
# | 스토리지      | S3, EBS, Glacier                  | Blob Storage, ADLS           | Cloud Sorage, Cloud SQL              |
# | 데이터베이스    | RDS, DynamoDB,Redshift            | Cosmos DB, Azure SQL         | Cloud SQL, Bigtable                  |
# | 네트워킹      | VPC, Route 53, DirectConnect      | Virtual Network,ExpressRoute | Virtual Private Cloud, Cloud DNS     |
# | 관리& 거버넌스  | IAM, CloudWatch, CloudFormation   | Azure Policy, Azure Monitor  | IAM, Stackdriver, Deploymnet Manager |
# | 인공지능 머신러닝 | SageMaker, Rekognition,Transcribe | Azure ML,Cognitive Service   | Cloud AI Platform, Cloud ML Engine   |
# | 사물인터넷     | IoT Core, Greengrass              | IoT Hub, IoT Central         | IoT Core, Cloud IoT Core             |
# | 빅데이터      | Redshift,Kinesis,EMR              | HDInsight, Data Lake         | BigQuery, Dataflow, Dataproc         |
# | 개발자 툴     | CodeStar, CodeCommit, CodeBuild   | Azure DevOps, Visual Studio  | Cloud SDK, Cloud Code, Cloud Build   |
#
#
# 📌 참고 1.[도서,Node.js백엔드개발자되기](https://product.kyobobook.co.kr/detail/S000201457949) <br>

# %% [markdown]
# 1.7 java script 생태계
# - 1995, 넷스케이프, html 동적 표현 목적 Mocha 스크립트 프로그래밍 언어로 탄생
# - JS 구조 기능 ECMAScript(ECMA-262) 언어 기본 규격 정의 국제 표준
#
# 1.7.1 패키지 메니저
# - npm, yarn
# - npm 은 Node.js 설치시 자동 설치됨(용량,속도,보안 문제 있음) -> yarn, pnpm 등으로 해결
#
# 1.7.2 빌드도구
# - \<script\> 태그를 사용하여 js 라이브러리 임포트 함.
# - webpack : 다양한 모듈 시스템 지원, 느림
# - ES6 이후 표준 모듈 시스템 빋르도구들(ESbuild,Vite) 등 ESM 만 지원 , 속도 빠름, 편리기능 추가
#
# 1.7.3 개발 도구
# - VSCode(에디터가 일렉트론으로 만들어짐.(이미 타입스크립트코드가 대거 포함된 상태))
# - jet brain 사의 WebStorm 도 있음. JS 디버깅, 단위 테스팅 등 기능 지원
#
# 1.7.4 웹 프레임 워크
# - React, Vue.js 사용하여 프론트엔드
# - Svelte(스벨트) 신흥 강자.
# - 벡엔드 (Express, NestJS)
#
# 1.7.5 백엔드 개발 환경
# - 디노(Deno) , Ryan Dahl, 일관된 개발 경험 제공
#
# 1.7.6 인프라
# - 풀루미 JS 코드로 클라우드 환경 기반 인프라 관리 , 개인용도 사용시 무료 기업용 유료

# %% [markdown]
# 용어 정리
# 1. 프로토콜 : 네트워크에 상 정보 주고 받게 규정한 규칙
# 2. 데이터베이스 : 검색과 축적을 위한 데이터 모음, 혹은 관리하는 애플리케이션 자체
# 3. 클라우드 : 인터넷 기반 컴퓨팅 환경 (IaaS, PaaS, SaaS)
# 4. 패키지매니저 : 패키지 설치 삭제 업데이트 프로그램
# 5. 프레임워크 : 소프트웨어 설계 구현, 재사용 가능하게끔 정리된 형태로 제공
# 6. 인프라: 구축에 필요한 자원
# 7. 소스 코드 관리 시스템 : 버전관리, 추적 관리, 공동 작업 지원
# 8. ㅁ
