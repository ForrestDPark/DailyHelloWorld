# %%
import warnings ;warnings.filterwarnings('ignore');import sys ;sys.path.append("../../")
from CustomFunc import *;import CustomFunc;print(CustomFunc.Basic());DataPreprocessing.plotSetting(setting_info=True);
import tensorflow as tf, numpy as np
y(f"Tensorflow version : {tf.__version__}")
import sys ;y("Python version :"+sys.version)
y("Needed library fetching complete.")
# Out:
# Custom Func Version : 1.0.1 -update 2024.10.28
#   ⁍ 현재 경로의 폴더 목록 --
#   폴더1 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/images
#   폴더2 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/__pycache__
#   폴더3 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/model
#   폴더4 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/Data
# ../ +  ../../ 경로 python path 에 추가.
# ◎ 주피터 가상환경  : base
# ◎ Python 설치 경로:/opt/anaconda3/bin/python
# ◎ Graph 한글화 Setting
# 패키지 목록이 package_list.txt 파일에 저장되었습니다.
#   - ◎ matplot graph set complete
# Tensorflow version : 2.17.0
# python version :3.11.7 (main, Dec 15 2023, 12:09:56) [Clang 14.0.6 ]
# Needed library fetching complete.

# %% [markdown]
# ---
# # 6. 임베딩을 사용한 감성 프로그래밍
