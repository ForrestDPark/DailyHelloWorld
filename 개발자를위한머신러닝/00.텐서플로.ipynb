# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.16.1'

# %%
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../")
from  CommonFunc_04 import *
DataPreprocessing.plotSetting(setting_info=True)
# Out:
#   ⁍ 현재 경로의 폴더 목록 --
#   폴더1 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/__pycache__
# ../ +  ../../ 경로 python path 에 추가.
# ◎ 주피터 가상환경  : base
# ◎ Python 설치 경로:/opt/anaconda3/bin/python
# ◎ Graph 한글화 Setting
# 패키지 목록이 package_list.txt 파일에 저장되었습니다.
#   - ◎ matplot graph set complete

# %%
# Out:
# 패키지 목록이 package_list.txt 파일에 저장되었습니다.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       7     return packages
#       9 if __name__ == "__main__":
# ---> 10     installed_packages = get_installed_packages()
#      11     for package in installed_packages:
#      12         print(package)
#
# Cell In[5], line 5, in get_installed_packages()
#       3 def get_installed_packages():
#       4     """현재 환경에 설치된 패키지 목록을 반환합니다."""
# ----> 5     installed_packages = pip.__package__()
#       6     packages = [package.project_name for package in installed_packages]
#       7     return packages
#
# TypeError: 'str' object is not callable
