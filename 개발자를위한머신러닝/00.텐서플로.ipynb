# %%
## page 40 예제 
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../")
from  CommonFunc_04 import *
DataPreprocessing.plotSetting(setting_info=True)
import tensorflow as tf
print(yellow(f"tensorflow version : {tf.__version__}"))
import tensorflow as tf, numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss="mean_squared_error")
xs = np.array([-1,0,1,2,3,4],dtype=float)
ys = np.array([-3,-1,1,3,5,7],dtype=float)
model.fit(xs,ys, epochs=400)
print(model.predict(np.array([10.0])))
# Out:
#   ⁍ 현재 경로의 폴더 목록 --
#   폴더1 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/__pycache__
# ../ +  ../../ 경로 python path 에 추가.
# ◎ 주피터 가상환경  : base
# ◎ Python 설치 경로:/opt/anaconda3/bin/python
# ◎ Graph 한글화 Setting
# 패키지 목록이 package_list.txt 파일에 저장되었습니다.
#   - ◎ matplot graph set complete
# tensorflow version : 2.16.1
# Epoch 1/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 53.6970
# Epoch 2/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 42.6542
# Epoch 3/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 33.9579
# Epoch 4/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 27.1078
# Epoch 5/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.7105
# Epoch 6/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.4563
# Epoch 7/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 14.1015
# Epoch 8/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.4546
# Epoch 9/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.3648
# Epoch 10/400
# ...

# %%
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../")
from  CommonFunc_04 import *
DataPreprocessing.plotSetting(setting_info=True)
import tensorflow as tf
print(yellow(f"tensorflow version : {tf.__version__}"))
import tensorflow as tf, numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

dense = Dense(units=1, input_shape=[1])
model = Sequential([dense])
model.compile(optimizer='sgd', loss="mean_squared_error")

xs = np.array([-1,0,1,2,3,4],dtype=float)
ys = np.array([-3,-1,1,3,5,7],dtype=float)
model.fit(xs,ys, epochs=400)
print(model.predict(np.array([10.0])))
print(yellow("신경망이 학습한것: {}".format(dense.get_weights())))
# Out:
#   ⁍ 현재 경로의 폴더 목록 --
#   폴더1 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/__pycache__
# ../ +  ../../ 경로 python path 에 추가.
# ◎ 주피터 가상환경  : base
# ◎ Python 설치 경로:/opt/anaconda3/bin/python
# ◎ Graph 한글화 Setting
# 패키지 목록이 package_list.txt 파일에 저장되었습니다.
#   - ◎ matplot graph set complete
# tensorflow version : 2.16.1
# Epoch 1/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 34.2758
# Epoch 2/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 27.2978
# Epoch 3/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.8011
# Epoch 4/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.4699
# Epoch 5/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 14.0557
# Epoch 6/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 11.3633
# Epoch 7/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.2387
# Epoch 8/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.5611
# Epoch 9/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.2352
# Epoch 10/400
# ...

# %%
W=dense.get_weights()[0][0][0]
b=dense.get_weights()[1][0]
print(yellow(f"신경망이 학습한것: Y  ={W}X + {b}"))
# Out:
# 신경망이 학습한것: Y  =1.9911763668060303X + -0.9726439714431763

# %% [markdown]
# ---
# ### Chapter 2. Computer Vision

# %%
import warnings ;warnings.filterwarnings('ignore');import sys ;sys.path.append("../../");from  CommonFunc_04 import *
import tensorflow as tf, numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import keras

data = tf.keras.datasets.fashion_mnist
(training_images,training_labels),(test_images,test_labels) \
    = data.load_data() ## data load 6만개의 훈련이미지, 1만개의 테스트이미지 

# 이미지 픽셀 값 0-1 로 정규화, 이미지는 정규화 하는게 tensorflow 에서는 무조건 성능이 높다. 
# 정규화 하지않으면 오류가 나거나 학습하지 못하는 경우도 생김. 
training_images= training_images/255.0 
test_images = test_images/255.0

model = keras.Sequential([
    
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(128,activation = tf.nn.relu),
    keras.layers.Dense(10,activation =tf.nn.softmax)
    
])
model.compile(optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])

model.fit(training_images,training_labels, epochs=5)

model.evaluate(test_images,test_labels)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7892 - loss: 0.6116
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 983us/step - accuracy: 0.8632 - loss: 0.3859
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 999us/step - accuracy: 0.8769 - loss: 0.3364
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 994us/step - accuracy: 0.8870 - loss: 0.3090
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8924 - loss: 0.2918
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 0.8750 - loss: 0.3498
# [0.348814994096756, 0.8748000264167786]

# %%
classifications = model.predict(test_images)

for i in range(len(test_images)):
    if i<10:
        print(f"{i+1}번째이미지는 {max(classifications[i])*100:.2f}%확률로 {test_labels[i]}입니다.")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 1번째이미지는 93.29%확률로 9입니다.
# 2번째이미지는 99.32%확률로 2입니다.
# 3번째이미지는 100.00%확률로 1입니다.
# 4번째이미지는 100.00%확률로 1입니다.
# 5번째이미지는 62.76%확률로 6입니다.
# 6번째이미지는 99.99%확률로 1입니다.
# 7번째이미지는 98.61%확률로 4입니다.
# 8번째이미지는 98.00%확률로 6입니다.
# 9번째이미지는 99.91%확률로 5입니다.
# 10번째이미지는 99.98%확률로 7입니다.

# %%
## Call back 을 이용해서 에포크 수를 자동으로 맞춰주자. 
import tensorflow as tf

class myCallback(tf.keras.callbacks.Callback): ## callback함수 를 상속함. 
    def on_epoch_end(self,epoch, logs={}):
        if(logs.get('accuracy')>0.95):
            print("\n 정확도 95% 에 도달하여 훈련을 멈춥니다.!!")
            self.model.stop_training = True

callbacks = myCallback()
mnist = tf.keras.datasets.fashion_mnist

(training_images,training_labels),(test_images,test_labels)\
=mnist.load_data()
    
## 이미지 정규화 
training_images =training_images/255.0
test_images = test_images/255.0

## 모델 컴파일 
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape = (28,28)),
    tf.keras.layers.Dense(128,activation = tf.nn.relu),
    tf.keras.layers.Dense(10,activation = tf.nn.softmax)
])

model.compile(optimizer='adam',
            loss = 'sparse_categorical_crossentropy',
            metrics= ['accuracy']
            )
model.fit(training_images,training_labels, epochs=50, callbacks=[callbacks])
# Out:
# Epoch 1/50
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 924us/step - accuracy: 0.7807 - loss: 0.6344
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 926us/step - accuracy: 0.8609 - loss: 0.3886
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 929us/step - accuracy: 0.8725 - loss: 0.3483
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 916us/step - accuracy: 0.8862 - loss: 0.3112
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 912us/step - accuracy: 0.8896 - loss: 0.2981
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 877us/step - accuracy: 0.8976 - loss: 0.2780
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 910us/step - accuracy: 0.9014 - loss: 0.2649
# Epoch 8/50
# ...

# %%
classifications = model.predict(test_images)

for i in range(len(test_images)):
    if i<10:
        print(f"{i+1}번째이미지는 {max(classifications[i])*100:.2f}%확률로 {test_labels[i]}입니다.")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step
# 1번째이미지는 99.97%확률로 9입니다.
# 2번째이미지는 99.93%확률로 2입니다.
# 3번째이미지는 100.00%확률로 1입니다.
# 4번째이미지는 100.00%확률로 1입니다.
# 5번째이미지는 72.45%확률로 6입니다.
# 6번째이미지는 100.00%확률로 1입니다.
# 7번째이미지는 99.64%확률로 4입니다.
# 8번째이미지는 99.99%확률로 6입니다.
# 9번째이미지는 100.00%확률로 5입니다.
# 10번째이미지는 100.00%확률로 7입니다.
