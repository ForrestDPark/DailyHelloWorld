# %%
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../")
from  CommonFunc_04 import *
DataPreprocessing.plotSetting(setting_info=True)
import tensorflow as tf
print(yellow(f"tensorflow version : {tf.__version__}"))
import tensorflow as tf, numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import keras
# Out:
#   ⁍ 현재 경로의 폴더 목록 --
#   폴더1 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/images
#   폴더2 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/__pycache__
#   폴더3 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/model
#   폴더4 :  /Users/forrestdpark/Desktop/PDG/DailyHelloWorld_/개발자를위한머신러닝/Data
# ../ +  ../../ 경로 python path 에 추가.
# ◎ 주피터 가상환경  : base
# ◎ Python 설치 경로:/opt/anaconda3/bin/python
# ◎ Graph 한글화 Setting
# 패키지 목록이 package_list.txt 파일에 저장되었습니다.
#   - ◎ matplot graph set complete
# tensorflow version : 2.16.1

# %% [markdown]
# 텐서플로 데이터 셋 목록
# - https://oreil.ly/zL7zq

# %%
# !pip install tensorflow-datasets
# Out:
# Collecting tensorflow-datasets
#   Downloading tensorflow_datasets-4.9.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: absl-py in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (2.1.0)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (8.1.7)
# Collecting dm-tree (from tensorflow-datasets)
#   Downloading dm_tree-0.1.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.9 kB)
# Collecting immutabledict (from tensorflow-datasets)
#   Downloading immutabledict-4.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (1.26.4)
# Collecting promise (from tensorflow-datasets)
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf>=3.20 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (3.20.3)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (5.9.0)
# Requirement already satisfied: pyarrow in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (16.1.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (2.31.0)
# Collecting simple-parsing (from tensorflow-datasets)
#   Downloading simple_parsing-0.1.6-py3-none-any.whl.metadata (7.3 kB)
# Collecting tensorflow-metadata (from tensorflow-datasets)
#   Downloading tensorflow_metadata-1.16.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: termcolor in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (2.4.0)
# Requirement already satisfied: toml in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (4.66.4)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets) (1.14.1)
# Collecting etils>=1.9.1 (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets)
#   Downloading etils-1.9.4-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2023.10.0)
# Collecting importlib_resources (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: typing_extensions in /opt/anaconda3/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.9.0)
# Requirement already satisfied: zipp in /opt/anaconda3/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow-datasets) (2024.8.30)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from promise->tensorflow-datasets) (1.16.0)
# Collecting docstring-parser<1.0,>=0.15 (from simple-parsing->tensorflow-datasets)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting googleapis-common-protos<2,>=1.56.4 (from tensorflow-metadata->tensorflow-datasets)
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf>=3.20 (from tensorflow-datasets)
#   Downloading protobuf-5.28.2-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Downloading tensorflow_datasets-4.9.6-py3-none-any.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 5.0 MB/s eta 0:00:00a 0:00:01
# Downloading etils-1.9.4-py3-none-any.whl (164 kB)
# Downloading dm_tree-0.1.8-cp311-cp311-macosx_11_0_arm64.whl (110 kB)
# Downloading immutabledict-4.2.0-py3-none-any.whl (4.7 kB)
# Downloading simple_parsing-0.1.6-py3-none-any.whl (112 kB)
# Downloading tensorflow_metadata-1.16.1-py3-none-any.whl (28 kB)
# Downloading protobuf-5.28.2-cp38-abi3-macosx_10_9_universal2.whl (414 kB)
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Building wheels for collected packages: promise
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21484 sha256=6cb16814dc440c42bae3097c701204a0203f1ed2e6184f8614d9f878b2e51bdd
#   Stored in directory: /Users/forrestdpark/Library/Caches/pip/wheels/90/74/b1/9b54c896b8d9409e9268329d4d45ede8a8040abe91c8879932
# Successfully built promise
# Installing collected packages: dm-tree, protobuf, promise, importlib_resources, immutabledict, etils, docstring-parser, simple-parsing, googleapis-common-protos, tensorflow-metadata, tensorflow-datasets
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.2 which is incompatible.
# Successfully installed dm-tree-0.1.8 docstring-parser-0.16 etils-1.9.4 googleapis-common-protos-1.65.0 immutabledict-4.2.0 importlib_resources-6.4.5 promise-2.3 protobuf-5.28.2 simple-parsing-0.1.6 tensorflow-datasets-4.9.6 tensorflow-metadata-1.16.1

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

mnist_data =tfds.load("fashion_mnist")
for i in mnist_data:
    print(i)
# Out:
# 2024-10-16 10:52:45.279855: W external/local_tsl/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Could not resolve host: metadata.google.internal".
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to /Users/forrestdpark/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling /Users/forrestdpark/tensorflow_datasets/fashion_mnist/incomplete.AM7BSO_3.0.1/fashion_mnist-train.tf…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling /Users/forrestdpark/tensorflow_datasets/fashion_mnist/incomplete.AM7BSO_3.0.1/fashion_mnist-test.tfr…
# Dataset fashion_mnist downloaded and prepared to /Users/forrestdpark/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# train
# test

# %%
mnist_train = tfds.load(name ='fashion_mnist' ,split='train')
assert isinstance(mnist_train, tf.data.Dataset)
print(type(mnist_train))
# Out:
# <class 'tensorflow.python.data.ops.prefetch_op._PrefetchDataset'>

# %%
for item in mnist_train.take(1):
    print(type(item))
    print(item.keys())
    
    print(item['image'])
    print(item['label'])
# Out:
# <class 'dict'>
# dict_keys(['image', 'label'])
# tf.Tensor(2, shape=(), dtype=int64)
# 2024-10-16 10:56:58.425646: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2024-10-16 10:56:58.426095: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# > mnist train 은 dict 타입이고 item 은 image, label 로 되어있음.
# > image 항목은 tf.Tensor type 28*28 배열임.
# > 레이블 : tf.Tensor(2, shape=(), dtype=int64)

# %%
mnist_test ,info = tfds.load(name='fashion_mnist', with_info="true")
info
# Out:
# tfds.core.DatasetInfo(
#     name='fashion_mnist',
#     full_name='fashion_mnist/3.0.1',
#     description="""
#     Fashion-MNIST is a dataset of Zalando's article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#     """,
#     homepage='https://github.com/zalandoresearch/fashion-mnist',
#     data_dir='/Users/forrestdpark/tensorflow_datasets/fashion_mnist/3.0.1',
#     file_format=tfrecord,
#     download_size=29.45 MiB,
#     dataset_size=36.42 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(28, 28, 1), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=10000, num_shards=1>,
#         'train': <SplitInfo num_examples=60000, num_shards=1>,
#     },
#     citation="""@article{DBLP:journals/corr/abs-1708-07747,
#       author    = {Han Xiao and
#                    Kashif Rasul and
#                    Roland Vollgraf},
#       title     = {Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning
#                    Algorithms},
#       journal   = {CoRR},
#       volume    = {abs/1708.07747},
#       year      = {2017},
#       url       = {http://arxiv.org/abs/1708.07747},
#       archivePrefix = {arXiv},
#       eprint    = {1708.07747},
#       timestamp = {Mon, 13 Aug 2018 16:47:27 +0200},
#       biburl    = {https://dblp.org/rec/bib/journals/corr/abs-1708-07747},
#       bibsource = {dblp computer science bibliography, https://dblp.org}
#     }""",
# )

# %%
(training_images, training_labels),(test_images, test_labels)=\
    tfds.as_numpy(tfds.load('fashion_mnist',
                            split  =['train','test'],
                            batch_size = -1,
                            as_supervised =True
                            ))

# %% [markdown]
# ---
# ### 4.2 케라스 모델에서 텐서플로 데이터 셋 사용하기
# - 케라스 데이터셋은 ndarray type 임. 텐서플로 데이터셋은 Dataset객체나ㅏ Tensor타입을 반환하기때문에 넘파이 배열로 바꾸려면 변환작업이 필요함

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels),(test_images, test_labels)=\
    mnist.load_data()
