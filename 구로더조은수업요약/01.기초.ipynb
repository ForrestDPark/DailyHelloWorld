# %% [markdown]
# # 01-3 수업용 문서
# ## 수업 관련 기술 스팩 트럼
# - 웹, 응용, 게임  <-> 빅데이터, ai, iot, bloc chain, ar/vr
# - 웹 프로 그래밍 분류
#     - Designer : 전문 기획자
#     - Web Designer : html, css , photo shop, UI
#     - Publishuer : 최종 View 작업.
#     - Programmer : 결과물 jsp 화면에 데이터 표출 , DB 작업.
#
# - 웹 프로그래밍 사용자 접접 기준 분류
#     - Front( 사용자 보이는 영역 )
#         - html, css, js(ecmascript), js frameworks( jQuery, Vue.js/ React/Angular/...)
#         - 모바일 전용 ( jQuery Mobile, Sencha Touch2, React Native)
#     - BackEnd(눈에 안보이는 영역)
#         - Jsp/Servlet, Php, asp, python
#         - DB
#             data base ( oracle, mysql, mariadb, ms-sql...)
#             db 구축 및 관리 (dba)
#         - 웹 서버 구축 및 관리 (Apache, Tomcat, Node.js, nginx)
#         - 서버 관리
#             - linux(local, IDC Center)
#             - Cloud 서버 관리 (AWS, GCP:Google cloud platform)
#             - 네트워크 관리( 대규모 접속 관리)
#             - 보안 관리
# - 응용 프로그래밍
#     - 클라이언트 개발
#         - 일반 언어 (C, C++, Java, Python)
#         - 4GL 류(Visual Basic, Delphi, Visual C++, C++ Builder, Power Builder)
#     - 서버 개발
#         - 서버 프로그래밍 ( C, C++, Java, Python)
#         - DB , 네트워크, 보안..
# - 게임 프로그래밍
#     - 클라이언트 개발
#         - 일반 언어 (C, C++, Java, WinAPI, DirectX)
#         - js 기반 언어 ( 페이스북 게임, 인터 tv 게임.) -> cocos2d-js, Unity3D
#         - 플래쉬(Flash) : 사양단계
#         - 게임 엔진 프로그래밍
#             - pc 게임, 콘솔 게임( unity 3d , unreal)
#             - ios 게임, android 게임 (cocos2d-x, unity3d , unreal)
#     - 서버 개발
#         - 서버 프로그래밍 (C++, C, java, python)
#         - db , network, sequrity
#
#
# - 클라우드 기반.
#     : 기본 인프라 클라우드 서비스 플렛폼에서 제공. 서버구입,장소,회선 유지 등 구축비용과 유지비용 절약. 사용한만큼 지불
#
# - 웹개발 수업범위
#     cgi & server page, 웹서비스(기능성, 개발 생산성)spring, springboot MVC server frame work, AJax => 비동기 웹앱( 경량서버 프레임웍, 프론트엔드 프레임 웍, Vue.js, React, angular
#
# - spring
#     : 스프링 프레임워크 코어 , 스프링 데이터, 스프링 시큐리티, 스프링 배치, 스프링 인터그레이션, 스프링 소셜.
#     - 정부 프레임워크가 스프링 mvc 기반임. 정부 프레임워크로 스프링을 배우는것도 좋음.
# ====43
# > 2024.12.10
#     - spring boot 최소한의 노력으로 스프링 기반 프로젝트 가능.
#     - spring mvc 에서 spring boot 변화 는 엔진을 바꾸는것과 같음.
#     - vue.js, react, angular 등은 선팅을 바꾸는 것과 같음.
# - 파이썬.
#     - gui, cli programming, data 분석 기능 막강. SPSS,SAS 등 고가 프로그램 대체.
#     - 자동화 처리 ( server job batch process , client 자동화 업무, excel macro, atomatic auction etc..)
#     - 웹 크롤링 ,데이터 분석 pandas, Django 웹개발.
# - 빅데이터
#     - hadooop 클러스터 컴퓨팅 framwork, scale out -up , Map-reduce, Apache spark,
#     - 데이터 사이언스, 데이터 엔지니어링
# - 블록체인
#     - 블록체인 핵심 기술( 암호화, 해시, 블록, 채굴, 개인키, 블록체인)
#     - 이더리움 기반 ( 솔리디티, DApp, web3.js, 이더리움 자바스크립트 api)
# == 10

# %% [markdown]
# # 프로그래밍 과정 기초

# %% [markdown]
# > 2024.12.10
#
# - 베이스 이미지 생성 :
#     spring boot 하려면 jdk17 가 필요한것 처럼
#     node 하려면 node, python 하려면 python, anaconda 등..
