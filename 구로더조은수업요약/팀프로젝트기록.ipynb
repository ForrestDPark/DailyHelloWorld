# %% [markdown]
# 단어장 에 대한 외래키 .
# 단어를 엑셀파일로. xml
# 이미지를 텍스트로?
# 크롤링?
# 엑셀로 변환해놓는다?
# 엑셀 단어 .
# 단어를 기사에서 ocr 로 크롤링을한다.
# 칼럼
# yn 으로 구분 코드 를 구분. 코드를 넣는다
#
# 본문만..
#
# 기사를 내가 찍어서 이
#
# - 웹에서 스크린샷으로 해도 되고   파일도 입력, 쓰기도 가능.
# - 패널에 사진올리기 추가
# - 사진찍기, 캡쳐 클릭할 수이있게
# -
# - 내단어장 상단 클릭
# - 학습하기 게임형식, 나만의 소설 만들기 등으로 학습 하는 방식
# - 레디스 사용하면 대용량 트래픽을 다루면 시간이 굉장히 줄어든다.
# - 마이에스큐엘 + 레디스()
# - 손글씨 인식도 된다. 모르는단어 쓰면 인식해서 db 에 저장.
