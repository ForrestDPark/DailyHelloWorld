# %% [markdown]
# > 2024.12.17 07:57
# # [알고리즘] 알고리즘에 대하여 01
# ---
#
#     📌 본 포스팅은  파이썬으로 알고리즘을 구현하는 내용을 다룹니다.
#     📌 [참고]
# ---
#
# ## **<span style="color:brown"> 1. 점근 표기법. </span>**
#
# - 5050 을 구하는데 101 번계산, 50번계산  후자가 더 좋은 알고리즘이다.
# - 빅오(Big-O) : 최악의 경우 연산량.
# - ex) 배열 내에 특정 숫자가 존재 여부 ->True False 반환
#
# ```Python
# arr = [3,5,6,1,2,4]
#
# def is_number_exit(num,arr):
#     return True  if num  in arr else False
#
# is_number_exit(3,arr) # True
# is_number_exit(120,arr) # False
#
# ```
# ☞ 가장 좋을 때는 1번, 가장 나쁠때는 n 번 계산 O(1), O(n)
#
# ## **<span style="color:brown"> 2.시공간 복잡도 </span>**
# - 알고리즘을 평가하는 법. 걸리는 시간, 설치시 용량이 적을 수록 빠름.
# - 시간복잡도 낮음 = 빠름, 공간복잡도 낮음 = 저용량, 현대는 시간복잡도가 더 중요함.
# - n^2 인지 n 인지 중요함. n 인지 2n 인지 n+3 인지는 중요하지 않다.
#
# [문제1.] 숫자목록 최빈값과 빈도수 출력
#
# ```Python
#
# def most_freq(numbers,method = 'O(n^2)'):
#     most_freq_num = 0
#     max_freq = 0
#     if method=='O(n^2)':
#         for first_num in numbers:
#             freq =0
#             for num in numbers:
#                 if first_num ==num:
#                     freq +=1
#             if freq >= max_freq:
#                 max_freq = freq
#                 most_freq_num = num
#
#     else : #O(n)
#         num = {}
#         for i in numbers:
#             # print(i,end=' ')
#             if i not in num.keys():
#                 num[i] = 0
#             num[i]+=(1 if  i in num.keys() else 0 )
#         print(num)
#         max_freq = 0
#         for key,item in num.items():
#             if item >=max_freq:
#                 max_freq = item
#                 most_freq_num =key
#     return most_freq_num, max_freq
# most_freq([1, 2, 3, 2, 1, 3, 1, 4, 2, 1], method='1')
#
# ```
#
# [문제2.] 문자열 팰린드롬(거꾸로해도 박도박)
#
# def

# %%
arr = [3,5,6,1,2,4]

def is_number_exit(num,arr):
    return True  if num  in arr else False

is_number_exit(3,arr) # True
is_number_exit(120,arr) # False


def most_freq(numbers,method = 'O(n^2)'):
    most_freq_num = 0
    max_freq = 0
    if method=='O(n^2)':
        for first_num in numbers:
            freq =0
            for num in numbers:
                if first_num ==num:
                    freq +=1
            if freq >= max_freq:
                max_freq = freq  
                most_freq_num = num     
                
    else : #O(n)
        num = {}
        for i in numbers:
            # print(i,end=' ')
            if i not in num.keys():
                num[i] = 0
            num[i]+=(1 if  i in num.keys() else 0 )
        print(num)
        max_freq = 0
        for key,item in num.items():
            if item >=max_freq:
                max_freq = item
                most_freq_num =key
    return most_freq_num, max_freq
most_freq([1, 2, 3, 2, 1, 3, 1, 4, 2, 1], method='1')
# Out:
# {1: 4, 2: 3, 3: 2, 4: 1}
# (1, 4)

# %% [markdown]
# # 스터디 어떻게 하고 강의 어떻게 하는지
# 2,3 주차 그래프 특강.
# 대면은 없음.
# - 노션  학습 질문 남기기
# - 짧은 기간 알고리즘 해결. 강제성. 화,목 방문 학습 , 특강, 문제풀이 , 정해진 분량까지를 매주차 완료를 해야함.
# - 개더 입장으로 출결 관리 됨. 종료 시점에도 출결 됨.
# - 질문 상주 게더에서
# - 1주차를 빨리 떼버리고 2주차를 최대한 빨리 시작하는게 좋다. 3~5 주차부터 어려워 지기 시작함.
# - 하루 16강 까지 수강 가능. 50% 이상 강의를 들어야 다음 강의 넘길수 있음.
# - 강의 완료후 문제풀이가 있음.
# - 진도율 100% 다들으면 평생 강의 소장 가능.
#
# - 알고리즘은 공략집이다.
# - GPT는 프롬프트의 우선순위를 어떻게 구현할까? 질문중에 중요한 질문과 덜중요한 질문
# 질문간에 우선순위 처리 방법? => 최대 힙 방법.
# - 배달의 민족 데이터 베이스 쿼리 최적화 이진트리
# - 최단거리 네이버 지도 : 다익스트라 알고리즘.
# - 머리를 써야함.
# - 필수 프로그램 설치
# - python download 3.11.3.
# - pytcharm community
# - 가상환경(virtual environment) 공구함.

# %%
# Basic
import sys,os ; sys.path.append("./../")
from DataPreprocessing_ import *

# %%
# Out:
# adult
# ['수박', '사과', '참외']
# 수박
# 참외
# ['수박', '사과', '참외']
# 수박
# 3
# hello eh. I am 르탄

# %%
a , b,c,d,e = 3,2, a +b, a*b, a/b
c,d,e

name = 'bob' # string
age = 143
isAdult  = 'adult' if age> 19 else 'not adult'
print(isAdult)

# list 
shop = ['수박', '사과', '참외']
print(shop)
print(shop[0])
print(shop[-1])
print(shop[:101])
print(shop[-3])
# print(shop[-4]) # IndexError: list index out of range 
def sum(a,b):
    return a+b 
print(sum(1,2))

# 클래스는 실제 세상과 비슷하게 만들기 위한 도구. 

class Person:
    def __init__(self,name):
        self.name =name
    
    def sayhello(self, toWhom):
        print(f"hello {toWhom}. I am {self.name}")

rtan = Person('르탄')
rtan.sayhello('eh')

# for gu in gus:
#     gu_name  =gu['MSRSTE_NM']
#     gu_mise = gu['IDEX_MVL']
#     if gu_mise <60:
#         print(gu_name,gu_mise)
        
def gu_mise(gu_name):
    import requests 
    r = requests.get('http://spartacodingclub.shop/sparta_api/seoulair')
    rjson =r.json()

    from pprint import pprint

    # pprint(rjson)
    gus = rjson['RealtimeCityAir']['row']
    for gu in gus:
        if gu ==gu_name:
            return gu_mise
        else : 
            print('non')
            return None

gu_mise('종로구')
# Out:
# non
