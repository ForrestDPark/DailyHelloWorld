# %% [markdown]
# # [블로그] 티스토리 SEO 를 위한 설정들
# ---
# <br>
#
# 참고 1. [티스토리, 2023, seo 필수설정 10](https://blog.naver.com/l2cache/223051840580)
#
# ---
#
#
#
#
# 1. 북클럽 스킨 설정
# html code 설정을 바꾼 사람은 스킨 변경시 모든 설정이 reset 될수있음. 백업 필요
#
# 2. 구글 서치콘솔 등록 .
#
# 3. 블로그 포스트 주소 문자로 설정하기
#
# 4. 메타 디스크립션
