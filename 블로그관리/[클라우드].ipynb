# %% [markdown]
# #[클라우드] MS Power Pages 에 대하여
# <!-- Comment-->
# 도메인을 만들어서 클라우드를 통해 웹 호스팅을 해야하는데 하나의 플랫폼에서 업무를 하고 도메인과 호스팅도 하나의 플랫폼에서 할수 있다면
# 호환성이 좋을 것 같았다. 예를들어 MS 문서(ppt,word,excel)를 storage 에 저장하고 그 자료를 통해 분석한 결과를
# 웹사이트에서 바로 서비스할수있게 하면 좋을 거라고 생각했다.
# 구글에서는 구글 사이트 애플리케이션이 있는데 MS 도 있겠지 하고 찾아봤는데 있었다.
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 MS Power Pages 는 무엇인가?</span>
# >✅ <span style="color: #0051abff">**파워페이지는**</span> 는 <span style="background-color: #fff5b1">**도메인 관리하는 MS 플랫폼이다.**</span> 이다.
#
# 1) Microsoft Power Platform 구성 요소와 함께 애플리케이션, 워크플로우, 지능형 가상 에이전트, 보고서 및 분석을 구축
# -   Microsoft Dataverse에 저장된 공유 비즈니스 데이터를 사용하여 사이트를 구
# -   비즈니스 웹 사이트를 만들고 호스팅하고 관리하기 위한 안전한 Enterprise 등급의 로우 코드 기반의 SaaS 플랫폼
# -   파워 페이지스 보안 취약성(접근제어 설정을 반드시 할것!)
#
# # <span style="color:#f17c6cff"> 🤔 MS Power Platform은 무엇인가?</span>
#
# # <span style="color:#f17c6cff"> 🤔 MS Power Pages 의 장단점은 무엇인가?</span>
# 1. 비용이 비싼편이다.
#
#
# 1.  power page 기능
# -   디자인 스튜디오
#     : 웹페이지 생성, 디자인, 관리 pages 작업, 스타일링, 데이터 기반 웹 애플리케이션 Dataverse 테이블
#     -   보안 작업공간 및 사이트 관리 공간.
# -   반응 형 렌더링
# -   개발자를 위한 VS code , power platform cli 기능
# -   보안 및 거버넌스
#
# 참고1. [출처 youtube : MS powerpages 홈페이지 제작, 2022](https://www.youtube.com/watch?v=pcIgSXzQpos)
# 참고2. [출처 naver blog : 파워페이지 기능, 2022](https://m.blog.naver.com/ilovehandson/222925045657)
# 참고3. [출처 보안뉴스, 2024](https://m.boannews.com/html/detail.html?idx=134494)
# 참고4. [출처 youtube power page 웹빌드01, 2023](https://www.youtube.com/watch?v=ny5Gua4cJk8)
# 참고5. [출처 naver blog, MS 파워페이지 copilot 출시 발표문](https://blog.naver.com/ilovehandson/223110850125)
# 참고6. [출처 power pages learn](https://learn.microsoft.com/en-us/power-pages/capabilities)

# %% [markdown]
# # [클라우드]Cloud storage 요금제 비교
# ---
# <br>
# 📌 요약 <br>
#
#
# ---
# <!--why write this article?-->
# 이글을 쓰게 된이유는?
# 웹서비스를 하기 위해서는 도메인과 호스팅 서버 가 필요하다. 호스팅 서버는 클라우드 업체에서 한다.
# 세상에는 많은 클라우드 업체가 있을 것이고 클라우드 업체의 장단점이 있을 것이다.
# 무엇을 비교해야할까? 우선 가격과 기술용이성, 편리성 등을 따져봐야한다.
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 어떤 클라우드 가 가장 가성비가 좋을까?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
#
# 📌 참고1. [티스토리,2024,클라우드 요금제 비교](https://everythin.tistory.com/136)

# %% [markdown]
# # [클라우드] Wix 에 대하여
#
# ---
# <!--이글을 쓰게 된 이유는?-->
# 가장많이 스는 도메인 호스팅 업체 중 Wix 라는 업체가 있다.
# Wix 의 제품을 사용할 때 어떤점이 좋고 나쁜지 장단점을 리뷰해 본다.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 Wix 란?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
#
#
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
#
#
# 1.  Wix 장점
#
# -   wix SEO 도우미 기능 이 있음.
# -   wix store 제품 페이지, wix 앱 마켓
# -   PG 사, KG 이니시스를 통한 국내 결제시스템(카카오 페이, 네이버 페이) 연결 가능
# -   SNS 채널(Instagram, facebook 등 ) 광고채널과의 손쉬운 통합.
#
# 1.1 Wix 결제기능 개선
#
# -   카카오로그인 지원 안함 ( 개발자 직접 코딩으로는 가능 )
# -   SEO check list 기능 있음. (SEO 한계 해결결)
# -   현재 kg 이니시스로 결제 방법 제공 함.(카카오, 네이버 가능)
#
# 2.  상황별 웹빌더 비교
#
# -   네이버 모두 : 네이버 SEO
#
# -   아임웹 : 노코드 국내 시스템 최적화
#
# -   wix : 해외사이트라는 단점. 커스텀 개발자 필요
#
# -   기타 : 버블, 어도비, 라이브클래스, 노션
#
#
# 3.  Wix 에 CUSTOM code 추가하는 방법
#
# -   wix editor X > embed > custum embed> embed a widget
#
# 📌 참고 1. [Youtube,2022, Wix Html 코드 삽입법](https://www.youtube.com/watch?v=zVqPqDkpjyM)
#
# 📌 참고 2. [Youtube,2024, 상황별 웹빌더 비교 (5~6분)](https://www.youtube.com/watch?v=gDdI8opcXN8)
#
# 📌 참고 3. [WixBlog,2024, 사이트빌더 비교](https://ko.wix.com/blog/post/best-ecommerce-website-builders)
#
# 📌 참고 4. [DotCle, wix 단점 정리](https://dotcle.kr/articles/?bmode=view&idx=127024464)

# %% [markdown]
# # [Web] 웹사이트 직접 구축하여 클라우드 서비스 하기
#
# ---
# <!--이글을 쓰게 된 이유는?-->
# 사실 나는 홈페이지 만들 수있고 만들어본 경험이 있다. 스프링 부트랑 DB 만 할줄알면
# 사이트 만드는 것은 어렵지 않다. 사이트 만들어서 서버에 올리고 공유 ip나 도메인 주소를 구매하면
# 그게 내 사이트가 되는 것이다. AWS 로 웹사이트 제작해서 배포하는 방법에 대해 알아보자.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 직접 웹사이트를 제작해서 클라우드에 올려야하는 이유?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
#
#
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
#
#
# 📌 참고 1. [웹사이트 직접 제작 이유](https://miraesystem.tistory.com/19)
#
# 📌 참고 2. [AWS 웹사이트 구축](https://brunch.co.kr/@topasvga/385)
#
# 📌 참고 3. [AWS 웹사이트 만들기](https://aws.amazon.com/ko/free/webapps/?gclid=CjwKCAiAmrS7BhBJEiwAei59i8EGVuRmBQlVv5emJic14BrAAASQ-k2uJa9wskf6UObXiInPxwauuRoCx4gQAvD_BwE&trk=625a54bc-636a-4278-b222-fbfde53ce712&sc_channel=ps&ef_id=CjwKCAiAmrS7BhBJEiwAei59i8EGVuRmBQlVv5emJic14BrAAASQ-k2uJa9wskf6UObXiInPxwauuRoCx4gQAvD_BwE:G:s&s_kwcid=AL!4422!3!588974988382!p!!g!!aws%20%EC%9B%B9%20%ED%98%B8%EC%8A%A4%ED%8C%85!16390049478!133992844699)

# %% [markdown]
# # [Web] SEO(Search engine optimization)에 대하여
#
#
# ---
# <!--이글을 쓰게 된 이유는?-->
# SEO 가 뭔지 궁금했다. SEO란 무엇이고 어떻게 SEO 를 평가하고 최적화 할수있는지 알아보자
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 SEO 란?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
#
#
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
#
#
# 📌 참고 1.[TBWA(seo 컨설팅업체),2024,SEO 총정리](https://seo.tbwakorea.com/blog/seo-guide-2022/)
# 📌 참고 2.[brunch,2024, SEO 에 대하여](https://brunch.co.kr/@dongdong1/22)
