# %% [markdown]
# # [Web] 웹빌더 선택 가이드
#
# ---
# <!--why write this article?-->
#
# 홈페이지에는 다양한 분류가 있고 홈페이지를 직접 프론트 작업을 통해서 만들지 않고 템플릿을 제공하는 업체가 많다.
# 업체들의 장단점을 따저보고 수치화 된 데이터로 분석 해보자.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 웹 빌더란?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
# 📌 참고 1.[DotCle 칼럼, 웹사이트 외주 가이드](https://dotcle.kr/articles/?q=YToxOntzOjEyOiJrZXl3b3JkX3R5cGUiO3M6MzoiYWxsIjt9&bmode=view&idx=128599140&t=board)<br>
#
#
# 분류별
#
# -   개인블로그
# -   이커머스 사이트
# -   브랜드 홈페이지
# -   포털 웹 애플리케이션
#
# 디자인측면
# 템플릿사용, 맞춤형디자인, 반응형 디자인
#
# 기능
#
# -   기본 : 텍스트,이미지, 양식제출기능
# -   고급 : 회원가입, 결제 시스템, 맞춤형 대시보드, 데이터 시각화
#
# 비용
#
# -   단순 랜딩 페이지 : 50~ 200 만
# -   소규모 기업 홈페이지 200-500
# -   이커머스 및 복잡한 웹 500 -800
# -   맞춤형 대기업 프로젝트 : 1500-
#
# 웹사이트 외주의 장단점.
#
# -   전문성 확보, 시간절약, 최신 트렌드, 비용
#
# 계약시 소유권 확인 필수
#
# 참고

# %% [markdown]
# # [Web] 워드프레스를 사용하는 방법
# ---
# <!--이글을 쓰게 된 이유는?-->
# 워드 프레스라는 웹사이트 제작 툴이라는게 있다고 한다. 이것은 어떤 툴인지 자세하게 알아보자.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 워드 프레스란?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
#
#
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
# 참고 1. [워드프레스 홈페이지](https://wordpress.com/ko/)
# 참고 2. [news,2024,워드프레스 시작 가이드](https://news.wp-kr.com/wordpress-start-guide/)

# %% [markdown]
# # [Web] 랜딩 페이지에 대하여
# ---
# <!--이글을 쓰게 된 이유는?-->
# 웹개발에대해 공부하다 보니 랜딩페이지라는 용어가 쓰이는데 뭔지 모르겠다. 알아보자
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 랜딩 페이지란?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
#
#
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
# 첫페이지.
#
# 📌 참고 1. [waveon, 2022,랜딩페이지 설명, 가이드](https://www.waveon.io/blog/landingpage?gad_source=1&gclid=CjwKCAiAmrS7BhBJEiwAei59i1YK3qi-T1XEU8_LjbOpw54PitCdku6yyZKigo8u-EHzZHOZ9Qh4PxoChBoQAvD_BwE)

# %% [markdown]
# # [Web] 구글 사이트로 만든 홈페이지에 결제기능 넣기
# ---
# <!--이글을 쓰게 된 이유는?-->
# 구글 플랫폼안에서 웹사이트는 무료로 만들 수있다. 하지만 결제기능을 넣을수 없는 단점이 있다고 한다.
# 사실일까? 결제기능 넣는 방법에 대해 알아보자.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 ecommerce 란?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
#
#
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
#
# 📌 참고 1. [ECWID,2021,구글사이트 ecommerse 기능 ](https://www.ecwid.com/ko/blog/google-sites-for-ecommerce.html)

# %% [markdown]
# # [Web] REST API 문서 작성하기
# ---
# <!--이글을 쓰게 된 이유는?-->
# REST api 를 사용해서 서비스를 해야할때 작성해야하는 문서라고 한다.
# 어떻게 작성하는지 알아보자.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 REST API 문서를 왜 써야할까?</span>
# >✅ <span style="color: #0051abff">**A**</span> 는 <span style="background-color: #fff5b1">**B**</span> 이다.
#
#
# # <span style="color:#f17c6cff"> 🤔 xyz?</span>
#
# 📌 참고 1. [카카오,2021,api doc 작성법](https://tech.kakaoenterprise.com/127)
#
# 📌 참고 2. [티스토리,2023,api 문서 작성](https://cobinding.tistory.com/165#API%20%EB%AC%B8%EC%84%9C%ED%99%94%EC%97%90%20%EB%93%A4%EC%96%B4%EA%B0%80%EC%95%BC%ED%95%A0%20%EB%82%B4%EC%9A%A9-1)
