# %% [markdown]
# # [구글] Google Docs 에 마크다운 올리기
# ---
# <!--이글을 쓰게 된 이유는?-->
#
# ***
#
# <img src="https://blog.kakaocdn.net/dn/b95UoH/btsLBJr7gMh/qwjkdfx5Sc9I2lUvkfMurk/img.png" data-mce-src="https://blog.kakaocdn.net/dn/b95UoH/btsLBJr7gMh/qwjkdfx5Sc9I2lUvkfMurk/img.png" data-origin-width="1696" data-origin-height="1082" data-is-animation="false" width="587" height="374" data-mce-selected="1">

# %% [markdown]
# # [글꼴] 윈도우에서 작성한 파워포인트가 맥북에서 깨짐현상 해결
# 나눔 글꼴이 맥북에는 없나보다. 설치하자.
#
# (1) [네이버글꼴](https://hangeul.naver.com/font) 접속 >
# (2) 나눔글꼴 전체 내려받기 클릭 > 다운로드 >
# (3) finder > Library > Fonts > 글꼴 이동 <br>
# <img src="https://blog.kakaocdn.net/dn/c3k5qT/btsLC08v6WP/SyzEwOciIFJQrvi3dnite1/img.png" data-mce-src="https://blog.kakaocdn.net/dn/c3k5qT/btsLC08v6WP/SyzEwOciIFJQrvi3dnite1/img.png" data-origin-width="2024" data-origin-height="968" data-is-animation="false" width="542" height="259" data-mce-selected="1">
#
# 하지만 그래도 ppt 에서 글꼴을 인식을 못하면 직접 ppt 글꼴이름과 매칭되는
# Font 가 있는지 확인해야한다.
# 나의 경우 한글이름의 글꼴은 없었다. 영어로 된것이있고 옆에 L 이 붙어있다
# 그리고 otf 의 경우 그래픽 전문 글꼴이기에 ttf(일반사용자) 파일이 아닌 otf 를 복사해주어야한다.
#
# <img src="https://blog.kakaocdn.net/dn/bQ83bP/btsLEZUoy6N/1FKnRCmvRKLR90CQVXIe1K/img.png" data-mce-src="https://blog.kakaocdn.net/dn/bQ83bP/btsLEZUoy6N/1FKnRCmvRKLR90CQVXIe1K/img.png" data-origin-width="702" data-origin-height="980" data-is-animation="false" width="469" height="655" data-mce-selected="1">
#
#
# 글꼴이름을 ppt 에서 지정하는대로 바꾼다.
# ppt 를 껏다가 킨다.
#
#
#
# 참고 1. [티스토리, 2020, 나눔글꼴 패키지 설치법](https://aboneu.tistory.com/286)

# %%
import pandas as pd

pd.read_csv("/Users/forrestdpark/Downloads/전국무료급식소표준데이터.csv",  encoding='utf-8',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 pd.read_csv("/Users/forrestdpark/Downloads/전국무료급식소표준데이터.csv",  encoding='utf-8',index_col=0)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %% [markdown]
# # [Mac] 맥북 엑셀 utf-8 설정, csv 한글 깨지는 문제 해결
# ---
# <!--💡이글을 쓰게 된 이유는 무엇인가요?-->
#
# |**😥 <span style="color:red"> 문제점</span>** | 맥북엑셀로 csv 파일을 열면 한글이 깨짐|
# |:--|:--|
# |**😫 나쁜영향** | **파일을 클릭해서 대충 데이터를 보고싶을 때 답답함**|
# |**✨ 해결방법** | <span style="color:#008080">**엑셀에서 설정을 세팅**</span>|
#
#
# ***
# <!-- 대표그림 -->
# ![깨진그림](https://a.okmd.dev/md/677bb10b15081.png)
#
# ***
#
#
# <!-- [Sequence] 이것이 실행되는 순서는 어떻게 되나요  -->
#
#
# ***
# <!-- [Sequence] 이것이 실행되는 순서는 어떻게 되나요  -->
# # **<span style="color:#21409a"> 🚶‍♂️UTF-8 설정 순서</span>**
#
# ### <span style="color:#21409a">**1. 데이터 세팅 하는 절차**<span>
#
# **(1) 엑셀- Data 탭 > GetData by txt 클릭**
# ### &emsp;&emsp;**✅ 아무런 변화가 없다!**
#
#
# ### <span style="color:#21409a">**2. python 으로 불러보자**<span>
# **(1) Pandas import > read_csv 실행**
# ```Python
# import pandas as pd
# pd.read_csv("/Users/(user이름)/Downloads/전국무료급식소표준데이터.csv",  encoding='utf-8',index_col=0)
# ```
# 실행하면 에러가 뜬다.
# ```Python
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbd in position 0: invalid start byte
# ```
# 인코딩 에러인데 파일이 EUC-KR 또는 CP949 인코딩으로 저장 되었는데 UTF-8 로 읽으려고 해서 문제가 발생하는 것이다. 이러니까 엑셀도 안읽히지..
# python 에서는 cp949 로 인코딩 하면 해결된다.
# ```Python
# import pandas as pd
# pd.read_csv("/Users/forrestdpark/Downloads/전국무료급식소표준데이터.csv",  encoding='cp949',index_col=0)
# ```
#
# ### <span style="color:#21409a">**3.엑셀에서 EUC-KR 로 데이터 보기**<span>
#
# **(1) Excel > Data > Get Data >Get Data(Power Query)**
# [##_Image|kage@bYfwLp/btsLF9W67Qz/ESHRK2kgz3dfgIkTLcMi8k/img.webp|CDM|1.3|{"originWidth":1228,"originHeight":1052,"style":"alignCenter","width":750,"height":643,"caption":"Get DAta power query 실행","filename":"Screenshot 2025-01-06 at 9.31.36 PM.webp"}_##]
#
# **(2) csv file 선택 > Get Data**
#
# [##_Image|kage@yQLWw/btsLFd0rHsV/7k1dgQBhXJaYljBpse7ra1/img.webp|CDM|1.3|{"originWidth":1640,"originHeight":922,"style":"alignCenter","width":744,"height":418,"caption":"Get data with txt","filename":"Screenshot 2025-01-06 at 9.09.55 PM.webp"}_##]
#
# **(3) 51949: Korean(EUC) 클릭**
#
# [##_Image|kage@bzxTFu/btsLGc0BsPW/4tNhG5pFkPJVdmiTyms7M1/img.webp|CDM|1.3|{"originWidth":1482,"originHeight":1108,"style":"alignCenter","width":757,"height":566,"caption":"EUC-KR 로 변환","filename":"Screenshot 2025-01-06 at 9.31.02 PM.webp"}_##]
#
# # 결과
#
# [##_Image|kage@bl9oBZ/btsLFZHb1V5/qnYllefTXuLz8g9GY3zkg0/img.webp|CDM|1.3|{"originWidth":1678,"originHeight":1130,"style":"alignCenter","width":758,"height":510,"caption":"잘 불러옴","filename":"Screenshot 2025-01-06 at 9.31.09 PM.webp"}_##]
#
#
#
#
# ***
# ### ℹ️ 참고
# 1.🌐 [조녁코딩일기 , 2022,오류해결](https://jonhyuk0922.tistory.com/232) <br>

# %% [markdown]
# # [블로그]. 맥북에서 캡쳐한 파일 webp로 자동 저장하게 설정하기
# ---
# <!--💡이글을 쓰게 된 이유는 무엇인가요?-->
# 😥 문제점 : 블로그 글을 올릴때 이미지가 png 로 올라가면 구글 검색최적화(SEO)에 매우 안좋다.
# 😫 나쁜영향 : SEO 가 나쁜 글을 올리면 블로그 수익화가 힘들다! 나는 가난하기때무네!
# ✨ 해결방법 : 홈브루로 cwebp 을 설치하고 오토메이트로 자동화 스크립트를 만들어 준다!
#
# ***
# ### <span style="color:#21409a">**1. 스크린샷 이미지가 .jpg 확장자로 저장하도록 하는 절차**<span>
# **(1) cmd + space (spotligt 열기)> terminal**
# **(2) 터미널창에서 다음 명령어를 실행**
# ```Bash
# defaults write com.apple.screencapture type jpg
# killall SystemUIServer # 적용
# ```
# **(3) 스크린샷 이미지가  jpg 확장자로 저장되는지 확인**
#
# [##_Image|kage@r1XB0/btsLFZNTSTr/SNbbVzWTb3k9pPAwWuKOU1/img.webp|CDM|1.3|{"originWidth":482,"originHeight":302,"style":"alignCenter","width":413,"height":259,"caption":"스크린샷 이 JPEG 로 저장됨","filename":"Screenshot 2025-01-06 at 7.47.36 PM.webp"}_##]
#
#
# ### <span style="color:#21409a">**2. 스크린샷 저장 폴더의 모든 이미지 파일이 webp 확장자로 변환하는 절차**<span>
# **(1) terminal > Homebrew webp 설치 명령어 입력**
# ```Bash
# $ brew install webp
# ```
#
# **(2)cmd +space > Automator.app 실행 > Folder action > choose > choose other >스크린샷이 저장되는 폴더를 선택 > open**
#
#
# [##_Image|kage@l7jMO/btsLFRCBqq9/ihKAXCjNxU5H937AxE3iMK/img.webp|CDM|1.3|{"originWidth":2004,"originHeight":1740,"style":"alignCenter","width":757,"height":657,"caption":"오토메이트 실행후 화면","filename":"Screenshot 2025-01-06 at 7.52.38 PM.webp"}_##]
#
#
# [##_Image|kage@ciAuzC/btsLGiGtdTJ/AzwEPqZy5H1rSuODAlcymK/img.webp|CDM|1.3|{"originWidth":1752,"originHeight":478,"style":"alignCenter","width":750,"height":205,"caption":"오토메이트 가 돌아갈 폴더 선택","filename":"Screenshot 2025-01-06 at 7.54.03 PM.webp"}_##]
# ***
# **💁‍♂️ 잠깐! 스크린샷을 데스크탑이아닌 다른 폴더로 저장되게 명령어는 ???**
# ```Bash
# defaults write com.apple.screencapture location (원하는 경로)
# ```
# [##_Image|kage@bCaPNH/btsLD2lmBTb/kG2pu0WKUPTcegcES68180/img.webp|CDM|1.3|{"originWidth":1604,"originHeight":494,"style":"alignCenter","width":759,"height":234,"caption":"스크린샷이 저장되는 폴더","filename":"Screenshot 2025-01-06 at 7.51.14 PM.webp"}_##]
# ***
#
#
#
# **(3) 우측 검색창 > Run Shell Script 더블클릭 > 명령어 입력**
#
# ```Bash
#
# SCREENSHOT_FOLDER="/Users/forrestdpark/Desktop/BlogImage"
#
# for file in "$SCREENSHOT_FOLDER"/*
# do
#     if [[ "$file" == *.jpg ]] || [[ "$file" == *.jpeg ]] || [[ "$file" == *.JPG ]] || [[ "$file" == *.JPEG ]] || [[ "$file" == *.png ]]
#     then
#         /opt/homebrew/bin/cwebp -q 75 "$file" -o "${file%.*}.webp"
#         if [ $? -eq 0 ]; then # cwebp 실행 성공 여부 확인
#            rm "$file" # 원본 파일 삭제
#            echo "Deleted: $file"
#         else
#             echo "Conversion failed for: $file"
#         fi
#     fi
# done
#
# echo "Conversion and cleanup complete."
# ```
# - for loop : 스크린샷 폴더의 파일 순회
# - then /opt~ : 파일 확장자를 확인하여 cwebp 명령어를 실행
# - "-q 75":  압축 품질 설정 옵션
# - rm ~ : 변환후 원본 파일을 삭제
# - echo : 실행 결과 출력
#
# [##_Image|kage@bEOHmG/btsLDV0O8xY/h1oYdYEI5D4v9dcWYh4LI1/img.webp|CDM|1.3|{"originWidth":1826,"originHeight":818,"style":"alignCenter","width":755,"height":338,"caption":"쉘 스크립트 실행","filename":"Screenshot 2025-01-06 at 7.55.37 PM.webp"}_##]
#
# [##_Image|kage@p8LPV/btsLEFXr2yD/rPcBOkjmWvVVjYTUj1e2tK/img.webp|CDM|1.3|{"originWidth":1258,"originHeight":718,"style":"alignCenter","width":755,"height":431,"caption":"쉘스크립트 코딩","filename":"Screenshot 2025-01-06 at 8.07.58 PM.webp"}_##]
#
# **(4) cmd +s (저장) > my script 입력 > save > allow**
#
# [##_Image|kage@csfksC/btsLGgaO6MK/myB1PXLHVsqyr7KpTYeLFk/img.webp|CDM|1.3|{"originWidth":1068,"originHeight":426,"style":"alignCenter","width":752,"height":300,"caption":"오토메이트 저장","filename":"Screenshot 2025-01-06 at 8.09.07 PM.webp"}_##]
#
#
# [##_Image|kage@Lv3MU/btsLENgTn5K/qsu2nX7KInYpOPZTFxLui0/img.webp|CDM|1.3|{"originWidth":2252,"originHeight":1008,"style":"alignCenter","width":746,"height":334,"caption":"webp 파일로 변환확인","filename":"Screenshot 2025-01-06 at 8.13.59 PM.webp"}_##]
#
# # 결과
#
# [##_Image|kage@Tzn7j/btsLEF4b223/OJnxt7sDNLxcOsA1kwggGK/img.webp|CDM|1.3|{"originWidth":680,"originHeight":222,"style":"alignCenter","width":751,"height":245,"caption":"기존 파일용량보다 4배 줄어드는것 확인","filename":"Screenshot 2025-01-06 at 8.17.45 PM.webp"}_##]
#
#
#
# ***
# ### ℹ️ 참고
# 1.🌐 [블로그,2023,Mac에서 찍은 스크린샷을 jpg, webp로 자동 변환하기](https://blogcreator.blog/post/55) <br>

# %% [markdown]
# # [MacOS] 맥북에서 gif 파일을 간단하게 만드는 방법
# ---
# <!-- 글작성일 : 2025.1.8 -->
# <!--💡이글을 쓰게 된 이유는 무엇인가요?-->
#
# ************************************************************
# |**😥 <span style="color:red"> 문제점 🧨</span>** |<span style="color:red"> javascript 결과물이 움직이는데 사진으로는 표현을 못함</span> |
# |:--|:--|
# |**<span style="color:#b181ebff">🧪나쁜영향😫</span>** | **<span style="color:#b181ebff">블로그 가독성이 떨어진다.</span>**|
# |**<span style="color:#008080">💁‍♂️해결방법💊</span>** | **<span style="color:#008080">Giphy Capture 를 설치한다. </span>**|
# ************************************************************
# ### ℹ️ 참고
#
# 1.🌐 [[Mac OS] 맥북에서 gif 만드는 방법 - Giphy Capture
# ](https://toberich.co.kr/entry/Mac-OS-%EB%A7%A5%EB%B6%81%EC%97%90%EC%84%9C-gif-%EB%A7%8C%EB%93%9C%EB%8A%94-%EB%B0%A9%EB%B2%95-Giphy-Capture) <br>
# ***
# <!-- 대표그림 -->
# *********************************************************************************
# <!-- [Sequence] 이것이 실행되는 순서는 어떻게 되나요  -->
# # **<span style="color:#21409a"> 🚶‍♂️ Giphy 설치, 실행 순서</span>**
#
# ### <span style="color:#21409a">**1. Giphy 절차**<span>
# **(1) 앱설치 > 앱 실행 > 화면선택 > 녹화시작 >종료 > 저장**
#
# [##_Image|kage@y5GhB/btsLIzOZ997/DFbB93B1Fb4G7I8h1pgML0/img.gif|CDM|1.3|{"originWidth":390,"originHeight":210,"style":"alignCenter","filename":"Jan-08-2025 17-14-18.gif"}_##]
