# %% [markdown]
# # [IT용어] SRE 엔지니어란?
# ---
# <!--이글을 쓰게 된 이유는?-->
# SRE 란 무엇인가 궁금 했다. DevOps 와 어떤 차이가 있는지 알아보자.
# ***
#
# <!-- Questions-->
# # <span style="color:#f17c6cff"> 🤔 SRE 엔지니어란?</span>
# > ### ✅ <span style="color: #0051abff">**SRE**</span> 는 <span style="background-color: #fff5b1">**사이트 안정성을 책임지는 업무**</span> 이다.
# - Site Reliability Engineering
# - 운영 업무를 담당하는 소프트웨어 엔지니어가 하는일
# - 릴리즈 주기 개선을 목표로 함.
#
# <!-- DevOPs 와 차이점은 무엇인가요 ? -->
# # ⚖️  DevOps 와 SRE 의 비교
# #### ⭐️ DevOps 는 무엇을 수행하는지 묻고 SRE 는 어떻게 사용할수 있는가를 묻는다.
#
#
# 📌 참고 1.[NetApp,SRE 정의](https://www.netapp.com/ko/devops-solutions/what-is-site-reliability-engineering/) <br>
