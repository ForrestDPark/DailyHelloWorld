# %% [markdown]
# # [Server] Azure 에 대하여
#
# 2. Azure 의 장단점 .
# - 장점: MS 제품 과 통합, 온프레미스와 하이브리드, 기업요구사항 위주 서비스, 글로벌 센터, 개발자 도구 생태계, 라이선스 유연성
#
# - 단점: MS 에 종속됨, 웹 콘솔 페이지 UI/UX 어려움, 대기업에 적합. 고비용
#
#
#
# 참고 [출처 검색: 온프레미스와 클라우드 차이  ](https://boardmix.com/kr/reviews/on-premises-vs-cloud/)
#
# 참고2. [출처 : 네이버 블로그, 2024](https://m.blog.naver.com/seek316/223350369932)
