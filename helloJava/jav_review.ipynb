# %% [markdown]
# ## Java 1주차 review .
# - version 11, 17, 18
# - 절차지향, 객체 지향.
# - JVM
# - Library(Java)
# - FrameWork(Spring)
#     - sprint, jsp,
#
# - memory :
#     heap, stack,
# - 암시적 형변환, 묵시적 형변환(double <- int )
# - camel type(java), pascal, snake type(sql, data analysis)
# - Const.
#     final int constNumber = 10;
#     constNumber = 100;
#     System.out.println(constNumber);
# - % 로 많은 것을 할수 있음(알고리즘의 출발)
#
# System.out.print("");
# Scanner
# -

# %% [markdown]
# # Jump to java 책 요약
# # 01-1
# - 제임스 고슬링. 객체 지향 프로그래밍.
# - jdk, ide , public, static
# # 02 자바시작
# # 03. 자료형
